# %% [markdown]
# Contents
# ---
# - [HTTP](#http)
# - [Sockets](#sockets)
# - [urllib](#urllib)
# - [urllib](#request)
# - [Web Scraping](#scraping)

# %% [markdown]
# This module is edited from Charles Severance's Python for Informatics book.
#
# HTTP
# ---
# <a class="anchor" id="http"></a>
#
# Let's now look at reading information from the internet instead of files.
#
# ### Sockets & HyperText Transport Protocol (HTML)
#
# The network protocol that powers the web is actually quite simple and there is built-in support in Python called sockets which makes it very easy to make network connections and retrieve data over those sockets in a Python program.
#
# A socket is much like a file, except that a single socket provides a two-way con- nection between two programs. You can both read from and write to the same socket. If you write something to a socket, it is sent to the application at the other end of the socket. If you read from the socket, you are given the data which the other application has sent.
#
#
# But if you try to read a socket when the program on the other end of the socket has not sent any data—you just sit and wait. If the programs on both ends of the socket simply wait for some data without sending anything, they will wait for a very long time.
#
#
# So an important part of programs that communicate over the Internet is to have some sort of protocol. A protocol is a set of precise rules that determine who is to go first, what they are to do, and then what the responses are to that message, and who sends next, and so on. In a sense the two applications at either end of the socket are doing a dance and making sure not to step on each other’s toes.
#
# There are many documents which describe these network protocols. The Hyper- Text Transport Protocol is described in the following document:
#
#
# http://www.w3.org/Protocols/rfc2616/rfc2616.txt
#
#
# This is a long and complex 176-page document with a lot of detail. If you find it interesting, feel free to read it all. But if you take a look around page 36 of RFC2616 you will find the syntax for the GET request. To request a document from a web server, we make a connection to the www.py4inf.com server on port 80, and then send a line of the form
#
#
# GET http://www.py4inf.com/code/romeo.txt HTTP/1.0
#
#
# where the second parameter is the web page we are requesting, and then we also send a blank line. The web server will respond with some header information about the document and a blank line followed by the document content.

# %% [markdown]
# Retrieving web pages using sockets
# ---
# <a class="anchor" id="sockets"></a>
#
# Let's write a simple Python program that makes a connection to a web server and follows the rules of the HTTP protocol to requests a document and display what the server sends back.
#
# Notice that the website http://data.pr4e.org/romeo.txt contains text from Romeo and Juliet. We can read it off the website using the following program:

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\n\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if (len(data) < 1):
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Fri, 02 Jun 2017 01:12:57 GMT
# Server: Apache/2.4.7 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already si
# ck and pale with grief

# %% [markdown]
# First the program makes a connection to port 80 on the server www.py4inf.com. Since our program is playing the role of the “web browser”, the HTTP protocol says we must send the GET command followed by a blank line.
#
# Once we send that blank line, we write a loop that receives data in 512-character chunks from the socket and prints the data out until there is no more data to read (i.e., the recv() returns an empty string).
#
# The output starts with headers which the web server sends to describe the document. For example, the Content-Type header indicates that the document is a plain text document (text/plain).
#
#
# After the server sends us the headers, it adds a blank line to indicate the end of the headers, and then sends the actual data of the file romeo.txt.
#
# This example shows how to make a low-level network connection with sockets. Sockets can be used to communicate with a web server or with a mail server or many other kinds of servers. All that is needed is to find the document which describes the protocol and write the code to send and receive the data according to the protocol.
#
#
# However, since the protocol that we use most commonly is the HTTP web protocol, Python has a special library specifically designed to support the HTTP protocol for the retrieval of documents and data over the web.

# %% [markdown]
# Retrieving web pages using urllib
# ---
# <a class="anchor" id="urllib"></a>
#
# While we can manually send and receive data over HTTP using the socket library, there is a much simpler way to perform this common task in Python by using the urllib library.
# Using urllib, you can treat a web page much like a file. You simply indicate which web page you would like to retrieve and urllib handles all of the HTTP protocol and header details.
# The equivalent code to read the romeo.txt file from the web using urllib is as follows:

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %% [markdown]
# Once the web page has been opened with urllib.request.urlopen, we can treat it like a
# file and read through it using a for loop. When the program runs, we only see the output of the contents of the file. The headers are still sent, but the urllib code consumes the headers and only returns the data to us.
#
# We can incorporate the code above to count the words

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

counts = {}
for line in fhand:
    words = line.split() 
    for word in words:
        counts[word] = counts.get(word,0) + 1 

counts_list=[]
for key, val in counts.items():
    counts_list.append((val,key))

counts_list.sort(reverse = True)
print(counts_list)
# Out:
# [(3, b'the'), (3, b'is'), (3, b'and'), (2, b'sun'), (1, b'yonder'), (1, b'with'), (1, b'window'), (1, b'what'), (1, b'through'), (1, b'soft'), (1, b'sick'), (1, b'pale'), (1, b'moon'), (1, b'light'), (1, b'kill'), (1, b'grief'), (1, b'fair'), (1, b'envious'), (1, b'east'), (1, b'breaks'), (1, b'already'), (1, b'Who'), (1, b'Juliet'), (1, b'It'), (1, b'But'), (1, b'Arise')]

# %% [markdown]
# Why is there a "b" before each word? It represents bytes. If we want to remove it, we can use .decode() on the values:

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

counts = {}
for line in fhand:
    words = line.split() 
    for word in words:
        counts[word] = counts.get(word,0) + 1 

counts_list=[]
for key, val in counts.items():
    counts_list.append((val,key.decode()))

counts_list.sort(reverse = True)
print(counts_list)
# Out:
# [(3, 'the'), (3, 'is'), (3, 'and'), (2, 'sun'), (1, 'yonder'), (1, 'with'), (1, 'window'), (1, 'what'), (1, 'through'), (1, 'soft'), (1, 'sick'), (1, 'pale'), (1, 'moon'), (1, 'light'), (1, 'kill'), (1, 'grief'), (1, 'fair'), (1, 'envious'), (1, 'east'), (1, 'breaks'), (1, 'already'), (1, 'Who'), (1, 'Juliet'), (1, 'It'), (1, 'But'), (1, 'Arise')]

# %% [markdown]
# Here's another example. Suppose we want to get information from the OES Faculty/Staff web page. Read the output carefully below to see where the faculty names are located.

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff')
for line in fhand:
    print(line.decode().strip())
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 8]>         <html lang="en-US" class="lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8">
#
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"87d38be11c","applicationID":"11580779","transactionName":"JVgLEhBaXg4BSxgTWQFSFkkKVFwGCFxoEFQTUA==","queueTime":0,"applicationTime":542,"agent":""}</script>
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"UwMPVVVUGwIBUVlSAAYO"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,n,e)])}catch(s){try{i("ierr",[s,c.now(),!0])}catch(u){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t){i("err",[t,c.now()])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=window.onerror,u=!1,d=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),u=!0)}s.on("fn-start",function(t,n,e){u&&(d+=1)}),s.on("fn-err",function(t,n,e){u&&(this.thrown=!0,o(e))}),s.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pus ...
# <title>Upper School Faculty &amp; Staff - OES</title>
# <link rel="icon" href="/uploaded/favicon.ico">
# <meta name="description" content="Upper School Faculty &amp; Staff - Oregon Episcopal School">
# <meta name="keywords" content="Upper School Faculty &amp; Staff, Oregon Episcopal School">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <link rel="canonical" href="https://www.oes.edu/academics/upper-school/faculty-staff">
# <meta property="og:url" content="https://www.oes.edu/academics/upper-school/faculty-staff">
# <meta property="og:description" content="Upper School Faculty &amp; Staff - Oregon Episcopal School">
# <meta property="og:title" content="Upper School Faculty &amp; Staff - OES">
# <meta property="og:type" content="website">
#
# <link rel="stylesheet" media="all" href="//static.finalsite.net/assets/application-576e2437b540b042b53dc059e8b146681fd3f4a6ca48a4166f1cf620fd626e82.css" />
#
#
#
# <!-- CF Styles Manager -->
# <link href="/styles.cfm?b" media="screen" rel="stylesheet">
#
# <link rel="stylesheet" media="all" href="/uploaded/themes/default2016-redesign/css/main.css?1490386593" />
#
# <script src="//static.finalsite.net/assets/in_layout_head-6e205639bc9a6ac0ef6b96704a4ad11c0a47a98dbdc16c0e42189cbd7a8402b7.js"></script>
#
# <script src="https://use.typekit.net/umt8nlk.js"></script>
# <script>try{Typekit.load({ async: true });}catch(e){}</script>
#
# <meta name="google-site-verification" content="ChHbB0fSWOrmC_rvlv-ldZNRVyXhPVC2Sxmi4RszbDo" />
#
#
# <script type="text/javascript">
# (function(window) {
# window.FS.currentPage = {
# dateFormat: 'md',
# timeFormat: '12'
# }
# })(window);
# </script>
#
#
# </head>
# <body data-logged-in="false" data-pageid="386" class="fsHasHeader fsHasLeftBanner fsHasMenu fsHasFooter fsHasOneColumnLayout fsSection154 fsHasTheme2">
#
# <script>
# dataLayer = [{ 'schoolDomain': 'www.oes.edu' }];
# dataLayer.push({'uaID': 'UA-5136820-1' });
#
# </script>
#
# <noscript>
# <iframe src="//www.googletagmanager.com/ns.html?id=GTM-P3BGC7"
# height="0" width="0" style="display:none;visibility:hidden">
# </iframe>
# </noscript>
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P3BGC7');
# </script>
#
#
# <div id="fsPageWrapper">
#
#
#
# <div id="fsMenu">
# <div class=" fsMenu fsStyleAutoclear" id="fsEl_493" >
#
# <div class="fsElement fsContent close-button-container" id="fsEl_920" >
#
# <div class="fsElementContent">
# <button class="drawer-trigger" href="#"></button>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_494" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li class="fsNavParentPage"><a href="/aboutoes/leadership">Leadership</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/leadership/board-of-trustees">Board of Trustees Information</a></li></ul></div></li><li class="fsNavParentPage"><a href="/aboutoes/strategic-plan">Strategic Plan</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/strategic-plan/program">Program</a></li><li><a href="/aboutoes/strategic-plan/people">People</a></li><li><a href="/aboutoes/strategic-plan/place">Place</a></li><li><a href="/aboutoes/strategic-plan/plan">Plan</a></li></ul></div></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li class="fsNavParentPage"><a href="/aboutoes/community-partnerships">Community Partnerships</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/community-partnerships/aardvarks-advocate-for-skills-knowledge-aask">Aardvarks Advocate for Skills &amp; Knowledge (AASK)</a></li><li><a href="/aboutoes/community-partnerships/community-conversations">Community Conversations</a></li><li><a href="/aboutoes/community-partnerships/spring-event">Spring Event</a></li></ul></div></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/admissions/inquire">Inquire</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/inquire/admissionsfaqs">Admissions FAQs</a></li><li><a href="/admissions/inquire/parent-tours">Parent Tours</a></li><li><a href="/admissions/inquire/student-visits">Student Visits</a></li><li><a href="/admissions/inquire/open-house">Open House</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/application-process">Application Process</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/application-process/ssat">SSAT</a></li><li><a href="/admissions/application-process/toefl">TOEFL</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/tuition-financial-aid/financial-aid-faqs">Financial Aid FAQs</a></li><li><a href="/admissions/tuition-financial-aid/faapplication">Financial Aid Application</a></li></ul></div></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/academics/academic-curriculum">Academic Curriculum</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/academics/academic-curriculum/our-approach">Our Approach</a></li><li class="fsNavParentPage"><a href="/academics/academic-curriculum/arts">Arts</a><div class="fsNavPageInfo"><ul class="fsNavLevel4"><li><a hr ...
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_1070" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li><a href="/contact-us">Contact Us</a></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_1071" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
#
# <header id="fsHeader" class="fsHeader">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_7" >
#
# <div class="fsElement fsContent logo-container" id="fsEl_69" >
#
# <div class="fsElementContent">
# <a href="/"><img alt="Oregon Episcopal School - ALWAYS OPEN" width="134" src="/uploaded/themes/default2016-redesign/images/logo.jpg"></a>
#
# </div>
#
#
# </div>
# <div class="fsElement fsContainer site-info-container" id="fsEl_921" >
#
# <div class="fsElementContent">
# <div class="fsElement fsContainer nav-holder" id="fsEl_922" >
#
# <div class="fsElementContent">
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_923" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_924" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li class="fsNavParentPage"><a href="/contact-us">Contact Us</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/contact-us/faculty-staff-directory">Employee Directory</a></li><li><a href="/contact-us/directions">Directions to Campus</a></li></ul></div></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsSearch site-search fsSearchField" id="fsEl_942" data-use-new="true">
#
# <div class="fsElementContent">
#
# <script>
# (function() {
# var scriptCoreId = 'fsSearchElementScriptCore';
#
# if(document.getElementById(scriptCoreId) == null) {
# var cx = '003863166793472101546:franr--wiru';
# var gcse = document.createElement('script');
# gcse.type = 'text/javascript';
# gcse.async = true;
# gcse.src = '//www.google.com/cse/cse.js?cx=' + cx;
# gcse.id = scriptCoreId;
# var s = document.getElementsByTagName('script')[0];
# s.parentNode.insertBefore(gcse, s);
#
# $(function() {
# // The search button is created by google's asynchronously loaded code after rendering and even after $(document).ready().
# // Likewise, the $(gcse).load() event also fires before the DOM elements we need to change are rendered.
# // We need to add an observer to find out when it's actually added so that we can adjust accordingly
# var observer = new MutationObserver(function() {
# $('input.gsc-search-button').attr('alt', 'Submit Search')
# });
# $('.gcse-searchbox-only').each(function() {
# observer.observe(this.parentNode, {childList: true, subtree: true});
# });
# });
# }
# })();
# </script>
#
# <div class="gcse-searchbox-only" data-as_sitesearch="www.oes.edu" data-resultsUrl="/search-results"></div>
#
#
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_925" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li><a href="/aboutoes/leadership">Leadership</a></li><li><a href="/aboutoes/strategic-plan">Strategic Plan</a></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li><a href="/aboutoes/community-partnerships">Community Partnerships</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/admissions/inquire">Inquire</a></li><li><a href="/admissions/application-process">Application Process</a></li><li><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/academics/academic-curriculum">Academic Curriculum</a></li><li><a href="/academics/lower-school">Lower School Home</a></li><li><a href="/academics/middle-school">Middle School Home</a></li><li class="fsNavCurrentPageAncestor"><a href="/academics/upper-school">Upper School Home</a></li><li><a href="/academics/libraries">Libraries</a></li></ul></div></li><li class="fsNavParentPage"><a href="/athletics">ATHLETICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/athletics/home-of-the-aardvarks">Home of the Aardvarks</a></li><li><a href="/athletics/full-athletic-calendar">Full Athletic Calendar</a></li><li><a href="/athletics/athletic-teams">Athletic Teams</a></li><li><a href="/athletics/ad-blog">Athletic Director's Blog</a></li><li><a href="/athletics/faqs">FAQs</a></li><li><a href="/athletics/concussion-protocol">Concussion Protocol</a></li><li><a href="/athletics/athletic-staff-coaches">Athletic Staff &amp; Head Coaches</a></li></ul></div></li><li class="fsNavParentPage"><a href="/student-life">STUDENT LIFE</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/student-life/service-learning">Service Learning</a></li><li><a href="/student-life/extension">Extension</a></li><li><a href="/student-life/experiential-education">Experiential Education</a></li><li><a href="/student-life/spiritual-growth">Spiritual Growth</a></li><li><a href="/student-life/health-well-being">Health &amp; Well Being</a></li><li><a href="/student-life/gathering">Gathering</a></li></ul></div></li><li class="fsNavParentPage"><a href="/support-oes">SUPPORT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/support-oes/giving-matters">Why Giving Matters</a></li><li><a href="/support-oes/annual-giving">Annual Giving</a></li><li><a href="/support-oes/endowed-funds">Endowed Funds</a></li><li><a href="http://oes.giftplans.org/">Gift Planning</a></li><li><a href="/support-oes/faq">FAQs</a></li><li><a href="/support-oes/meet-the-team">Meet the Team</a></li><li><a href="/support-oes/make-your-gift">Make Your Gift</a></li></ul></div></li><li class="fsNavParentPage"><a href="/news">NEW ...
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </header>
#
# <div id="fsPageBodyWrapper" class="fsPageBodyWrapper">
# <div id="fsPageBody" class="fsStyleAutoclear fsPageBody">
#
# <div id="fsBannerLeft" class="fsBannerLeft">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_8" >
#
# <div class="fsElement fsNavigation fsList nav-sub" id="fsEl_44" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/academics/academic-curriculum">Academic Curriculum</a></li><li><a href="/academics/lower-school">Lower School Home</a></li><li><a href="/academics/middle-school">Middle School Home</a></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics/upper-school">Upper School Home</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/academics/upper-school/academics">Academics</a></li><li><a href="/academics/upper-school/co-curriculum">Co-Curriculum</a></li><li><a href="/academics/academic-curriculum/arts">Arts</a></li><li><a href="/academics/upper-school/counseling-academic-support">Counseling &amp; Academic Support</a></li><li><a href="/academics/upper-school/college-counseling">College Counseling</a></li><li class="fsNavCurrentPage"><a href="/academics/upper-school/faculty-staff">Upper School Faculty &amp; Staff</a></li><li><a href="/academics/upper-school/voice-newsletter">Voice Newsletter</a></li></ul></div></li><li><a href="/academics/libraries">Libraries</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <main id="fsPageContent" class="fsPageContent">
# <h1 class="fsPageTitle">Upper School Faculty &amp; Staff</h1>
#
#
#
#
# <div class="fsPageLayout fsLayout fsOneColumnLayout fsStyleAutoclear" id="fsEl_2480" >
#
# <div class=" fsDiv fsStyleAutoclear" id="fsEl_2481" >
#
# <div class="fsElement fsConstituent fsSearch fsThumbnailOriginal fsThumbnailSmall" id="fsEl_3624" >
#
# <div class="fsElementContent">
# <form class="fsConstituentSearchForm" action="/academics/upper-school/faculty-staff" accept-charset="UTF-8" method="get"><input name="utf8" type="hidden" value="&#x2713;" />
# <input type="hidden" name="const_search_group_ids" value="131">
# <input type="hidden" name="const_search_role_ids" value="1">
#
# <label>
# <span>Keyword</span>
# <input type="text" name="const_search_keyword" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
#
# <label>
# <span>First Name</span>
# <input type="text" name="const_search_first_name" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
# <label>
# <span>Last Name</span>
# <input type="text" name="const_search_last_name" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
#
#
#
# <label>
# <span>Department</span>
# <select name="const_search_department">
# <option value="">All Departments</option>
# <option value="265">AASK</option>
# <option value="245">Administration</option>
# <option value="239">Athletics</option>
# <option value="266">Basketball</option>
# <option value="246">Chaplaincy</option>
# <option value="247">College Counseling</option>
# <option value="263">Community Partnerships</option>
# <option value="270">Counseling</option>
# <option value="261">Cross Country</option>
# <option value="232">Dorms</option>
# <option value="260">ELS</option>
# <option value="235">English</option>
# <option value="257">Experiential Education</option>
# <option value="243">Extension</option>
# <option value="268">Golf</option>
# <option value="255">History</option>
# <option value="225">Information Technology</option>
# <option value="269">Lacrosse</option>
# <option value="283">Librarians-Head</option>
# <option value="252">Library</option>
# <option value="244">Mathematics</option>
# <option value="240">Music</option>
# <option value="279">Nurse &amp; Athletic Trainer</option>
# <option value="237">Physical Education</option>
# <option value="253">Private Lessons</option>
# <option value="259">Religion &amp; Philosophy</option>
# <option value="249">Science</option>
# <option value="256">Service Learning</option>
# <option value="273">Skiing</option>
# <option value="267">Soccer</option>
# <option value="236">Student Support</option>
# <option value="250">Tennis</option>
# <option value="254">Track &amp; Field</option>
# <option value="231">Upper School Administration</option>
# <option value="278">US Counseling &amp; Academic Support</option>
# <option value="241">Visual &amp; Performing Arts (VaPA)</option>
# <option value="271">Volleyball</option>
# <option value="227">World Languages</option>
# </select>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <input type="submit" class="fsConstituentSearchButton fsStyleUpdateButton" value="Search Directory">
# </form>
# </div>
#
#
# </div>
# <div class="fsElement fsConstituent fsDirectory fsThumbnailOriginal fsThumbnailLarge" id="fsEl_3623" >
#
# <div class="fsElementContent">
#
# <div class="fsElementPagination" data-searchparams="{}">
#
#
#
# <a href="?const_page=1&amp;" data-page="1" class="fsFirstPageLink" disabled="disabled">1</a>
#
#
#
#
# <a href="?const_page=2&amp;" data-page="2">2</a>
# <a href="?const_page=3&amp;" data-page="3">3</a>
# <a href="?const_page=5&amp;" data-page="5">&hellip;</a>
#
# <a href="?const_page=6&amp;" data-page="6" class="fsLastPageLink">6</a>
#
# <a href="?const_page=2&amp;" data-page="2" data-searchparams="{}" class="fsNextPageLink">&gt;</a>
#
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>
#
# <div class="fsConstituentColumnLayout_3 fsStyleAutoclear">
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Deri Bash " src="/uploaded/New_Site/Employee_Directory/Deri_Bash.jpg" /></div>
#
# <h3 class="fsFullName">
# Deri Bash
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Associate Head of Upper School for Academics & Residential Life
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Upper School Administration, Dorms
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2478-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2478-directory", "ude.seo", "dhsab", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9357">
# 503-416-9357
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Brad Baugher " src="/uploaded/New_Site/Employee_Directory/Brad_Baugher.jpg" /></div>
#
# <h3 class="fsFullName">
# Brad Baugher
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Director of Educational Technology
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Information Technology
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2480-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2480-directory", "ude.seo", "brehguab", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3136">
# 503-768-3136
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Carmen Boyle " src="/uploaded/New_Site/Employee_Directory/Carmen_Boyle.jpg" /></div>
#
# <h3 class="fsFullName">
# Carmen Boyle
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Spanish Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2488-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2488-directory", "ude.seo", "celyob", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9238">
# 503-416-9238
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Peter Buonincontro " src="/uploaded/New_Site/Employee_Directory/Peter_Buonincontro.jpg" /></div>
#
# <h3 class="fsFullName">
# Peter Buonincontro
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Residential House Head, Theater & Performing Arts Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Dorms, Visual & Performing Arts (VaPA)
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2493-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2493-directory", "ude.seo", "portnocninoub", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3171">
# 503-768-3171
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Eduard Cecere " src="/uploaded/New_Site/Employee_Directory/Eduardo_Cecere.jpg" /></div>
#
# <h3 class="fsFullName">
# Eduard Cecere
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Upper School Technology Coordinator
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Information Technology
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2497-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2497-directory", "ude.seo", "eerecec", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9354">
# 503-416-9354
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Dennis Chang " src="/uploaded/New_Site/Employee_Directory/Dennis_Chang.jpg" /></div>
#
# <h3 class="fsFullName">
# Dennis Chang
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Algebra Teacher, Head JV Girls' Soccer Coach
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Athletics, Mathematics
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2499-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2499-directory", "ude.seo", "dgnahc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9289">
# 503-416-9289
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Chiman Chen " src="/uploaded/New_Site/Employee_Directory/Chiman_Chen.jpg" /></div>
#
# <h3 class="fsFullName">
# Chiman Chen
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Mandarin Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2500-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2500-directory", "ude.seo", "cnehc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9267">
# 503-416-9267
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Corbet Clark " src="/uploaded/New_Site/Employee_Directory/Corbet_Clark.jpg" /></div>
#
# <h3 class="fsFullName">
# Corbet Clark
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Interim Head of Upper School
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Upper School Administration, Administration
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2501-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2501-directory", "ude.seo", "ckralc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3121">
# 503-768-3121
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Jenny Cleveland " src="/uploaded/New_Site/Employee_Directory/Jenny_Cleveland.jpg" /></div>
#
# <h3 class="fsFullName">
# Jenny Cleveland
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Chaplain, College Counselor
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Chaplaincy, College Counseling
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2504-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2504-directory", "ude.seo", "jdnalevelc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9242">
# 503-416-9242
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Bevin Daglen " src="/uploaded/New_Site/Employee_Directory/Bevin_Daglen.jpg" /></div>
#
# <h3 class="fsFullName">
# Bevin Daglen
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Science Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Science
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2508-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2508-directory", "ude.seo", "bnelgad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9320">
# 503-416-9320
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Tessa Daniel " src="/uploaded/New_Site/Employee_Directory/Tessa_Daniel.jpg" /></div>
#
# <h3 class="fsFullName">
# Tessa Daniel
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Spanish Teacher, Yearbook
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2510-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2510-directory", "ude.seo", "tleinad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9297">
# 503-416-9297
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Coleen Davis " src="/uploaded/New_Site/Employee_Directory/Coleen_Davis.jpg" /></div>
#
# <h3 class="fsFullName">
# Coleen Davis
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Physical Education Teacher, Head Girls' Tennis Coach, SPARC Manager
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Physical Education, Athletics, Tennis
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2511-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2511-directory", "ude.seo", "csivad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3175">
# 503-768-3175
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
# </div>
# <div class="fsElementPagination" data-searchparams="{}">
#
#
#
# <a href="?const_page=1&amp;" data-page="1" class="fsFirstPageLink" disabled="disabled">1</a>
#
#
#
#
# <a href="?const_page=2&amp;" data-page="2">2</a>
# <a href="?const_page=3&amp;" data-page="3">3</a>
# <a href="?const_page=5&amp;" data-page="5">&hellip;</a>
#
# <a href="?const_page=6&amp;" data-page="6" class="fsLastPageLink">6</a>
#
# <a href="?const_page=2&amp;" data-page="2" data-searchparams="{}" class="fsNextPageLink">&gt;</a>
#
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>
#
#
# </div>
#
#
# </div>
#
#
#
#
# </div>
#
#
#
#
# </div>
#
#
#
# </main>
# </div>
# </div>
#
# <footer id="fsFooter" class="fsFooter">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_9" >
#
# <div class="fsElement fsContainer address-utility" id="fsEl_946" >
#
# <div class="fsElementContent">
# <div class="fsElement fsContent" id="fsEl_947" >
#
# <div class="fsElementContent">
# <div itemtype="http://schema.org/EducationalOrganization" class="school-details">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
# <span itemprop="addressRegion">OR</span>,
# <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-footer" id="fsEl_948" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <div class="fsElement fsContent tagline" id="fsEl_949" >
#
# <div class="fsElementContent">
# <p></p><p>Oregon Episcopal School is a college preparatory, independent school in Portland, Oregon, serving 860 students from Pre-Kindergarten through Grade 12, including 60 boarding students from around the world in Grades 9-12.</p><p></p>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-social" id="fsEl_950" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://www.facebook.com/oregon.episcopal" target="_blank">Facebook</a></li><li><a href="http://twitter.com/oregonepiscopal" target="_blank">Twitter</a></li><li><a href="http://www.youtube.com/user/OESTV" target="_blank">Youtube</a></li><li><a href="https://instagram.com/oregonepiscopal" target="_blank">Instagram</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
#
#
# </div>
#
#
# </footer>
#
# <div id="fsPoweredByFinalsite">
# <div>
# <a href="http://www.finalsite.com" target="_blank">Powered by Finalsite</a>
# </div>
# </div>
#
#
#
# </div>
#
#
#
#
#
# <script src="//static.finalsite.net/assets/application-8ee0832aea95b0177619c7a0f1966aadcab36725af74a145f58c313cec8abc6b.js"></script>
#
# <script src="/uploaded/themes/default2016-redesign/js/main.js?1490386593"></script>
#
#
#
#
#
# </body></html>

# %% [markdown]
# The names seem to be located below a line that contains the term "FullName." We can make a loop to print out just the names:

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff')
next = False
for line in fhand:
    if next == True:
        print(line.decode().strip())
        next= False
    if b'FullName' in line:
        next=True
# Out:
# Deri Bash
# Brad Baugher
# Carmen Boyle
# Peter Buonincontro
# Eduard Cecere
# Dennis Chang
# Chiman Chen
# Corbet Clark
# Jenny Cleveland
# Bevin Daglen
# Tessa Daniel
# Coleen Davis

# %% [markdown]
# ### Exercise - Socket 1
# Change the socket program to prompt the user for the URL so it can read any web page, not just the Romeo text. You can use split('/') to break the URL into its component parts so you can extract the host name for the socket connect call. Add error checking using try and except to handle the condition where the user enters an improperly formatted or non-existent URL.

# %%
#insert socket 1 exercise

# %% [markdown]
# ### Exercise - Socket 2
# Change your socket program so that it counts the number of characters it has received and stops displaying any text after it has shown 3000 characters. The program should retrieve the entire document and count the total number of characters and display the count of the number of characters at the end of the document.

# %%
#insert socket 2 exercise

# %% [markdown]
# ### Exercise - urllib 1
# Use urllib to replicate the Socket Exercise 1 by retrieving the document from a URL, (2) displaying up to 3000 characters, and (3) counting the overall number of characters in the document. Don't worry about the headers for this exercise, simply show the first 3000 characters of the document contents.

# %%
#insert urllib 1 exercise

# %% [markdown]
# Retrieving web pages using request
# ---
# <a class="anchor" id="request"></a>
#
# Hopefully, you are finding urllib pretty easy to use at this point, but wait, there's more. There's actually an even easier way to access info from the web by using the requests package. Recall that in order to get the Romeo text, we needed to type all this:

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
for line in fhand:
    print(line.decode().strip())

# %% [markdown]
# Even easier, let's use requests:

# %%
import requests

url = 'http://data.pr4e.org/romeo.txt'
response = requests.get(url)
print(response.text)
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %% [markdown]
# Web Scraping using BeautifulSoup
# ---
# <a class="anchor" id="scraping"></a>
#
# One of the common uses of the urllib capability in Python is to scrape the web. Web scraping is when we write a program that pretends to be a web browser and retrieves pages, then examines the data in those pages looking for patterns.
#
# As an example, a search engine such as Google will look at the source of one web page and extract the links to other pages and retrieve those pages, extracting links, and so on. Using this technique, Google spiders its way through nearly all of the pages on the web.
#
#
# Google also uses the frequency of links from pages it finds to a particular page as one measure of how “important” a page is and how high the page should appear in its search results.
#
# BeautifulSoup is one Python package that helps us to scrape the web. BeautifulSoup tolerates highly flawed HTML and still lets you easily extract the data you need.
#
# To download it, if you have a Mac, type "pip install beautifulsoup4" into your terminal. If that doesn't work or if you have a PC, download it directly from this website: https://www.crummy.com/software/BeautifulSoup/

# %% [markdown]
# Okay, let's first view what information is contained on the following page:

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('http://www.dr-chuck.com/page1.htm').read()
print(fhand.decode())
# Out:
# <h1>The First Page</h1>
# <p>
# If you like, you can switch to the
# <a href="http://www.dr-chuck.com/page2.htm">
# Second Page</a>.
# </p>

# %% [markdown]
# Notice that using HTML, headers are contained between the "h1" terms, web link tags are contained within the "a" terms, and paragraphs within the "p" terms. Thus, if we wanted to use BeautifulSoup to search for just the web links, we could type the following:

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('http://www.dr-chuck.com/page1.htm').read()

soup = BeautifulSoup(fhand, "html.parser")

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))
# Out:
# http://www.dr-chuck.com/page2.htm

# %% [markdown]
# If we want to get more specific with all of the different types of info stored in the tags, we can type:

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('http://www.dr-chuck.com/page1.htm').read()

soup = BeautifulSoup(fhand, "html.parser")

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    # Look at the parts of a tag
    print('TAG:', tag)
    print('URL:', tag.get('href', None))
    print('Contents:', tag.contents[0])
    print('Attrs:', tag.attrs)
# Out:
# TAG: <a href="http://www.dr-chuck.com/page2.htm">
# Second Page</a>
# URL: http://www.dr-chuck.com/page2.htm
# Contents:
# Second Page
# Attrs: {'href': 'http://www.dr-chuck.com/page2.htm'}

# %% [markdown]
# We notice that the entire HTML tag is stored in "tag", the URL alone can be accessed by tag.get('href', None), etc.
#
# If we wanted instead to search for the headers, we could use "h1":

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('http://www.dr-chuck.com/page1.htm').read()

soup = BeautifulSoup(fhand, "html.parser")

headers = soup('h1')
print(headers)
# Out:
# [<h1>The First Page</h1>]

# %% [markdown]
# Let's return to our OES faculty example. Look carefully at the teachers' names. Where are they stored? Inside "h3"'s:

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff')
for line in fhand:
    print(line.decode().strip())
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 8]>         <html lang="en-US" class="lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8">
#
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"87d38be11c","applicationID":"11580779","transactionName":"JVgLEhBaXg4BSxgTWQFSFkkKVFwGCFxoEFQTUA==","queueTime":0,"applicationTime":456,"agent":""}</script>
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"UwMPVVVUGwIBUVlSAAYO"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,n,e)])}catch(s){try{i("ierr",[s,c.now(),!0])}catch(u){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t){i("err",[t,c.now()])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=window.onerror,u=!1,d=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),u=!0)}s.on("fn-start",function(t,n,e){u&&(d+=1)}),s.on("fn-err",function(t,n,e){u&&(this.thrown=!0,o(e))}),s.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pus ...
# <title>Upper School Faculty &amp; Staff - OES</title>
# <link rel="icon" href="/uploaded/favicon.ico">
# <meta name="description" content="Upper School Faculty &amp; Staff - Oregon Episcopal School">
# <meta name="keywords" content="Upper School Faculty &amp; Staff, Oregon Episcopal School">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <link rel="canonical" href="https://www.oes.edu/academics/upper-school/faculty-staff">
# <meta property="og:url" content="https://www.oes.edu/academics/upper-school/faculty-staff">
# <meta property="og:description" content="Upper School Faculty &amp; Staff - Oregon Episcopal School">
# <meta property="og:title" content="Upper School Faculty &amp; Staff - OES">
# <meta property="og:type" content="website">
#
# <link rel="stylesheet" media="all" href="//static.finalsite.net/assets/application-576e2437b540b042b53dc059e8b146681fd3f4a6ca48a4166f1cf620fd626e82.css" />
#
#
#
# <!-- CF Styles Manager -->
# <link href="/styles.cfm?b" media="screen" rel="stylesheet">
#
# <link rel="stylesheet" media="all" href="/uploaded/themes/default2016-redesign/css/main.css?1490386593" />
#
# <script src="//static.finalsite.net/assets/in_layout_head-6e205639bc9a6ac0ef6b96704a4ad11c0a47a98dbdc16c0e42189cbd7a8402b7.js"></script>
#
# <script src="https://use.typekit.net/umt8nlk.js"></script>
# <script>try{Typekit.load({ async: true });}catch(e){}</script>
#
# <meta name="google-site-verification" content="ChHbB0fSWOrmC_rvlv-ldZNRVyXhPVC2Sxmi4RszbDo" />
#
#
# <script type="text/javascript">
# (function(window) {
# window.FS.currentPage = {
# dateFormat: 'md',
# timeFormat: '12'
# }
# })(window);
# </script>
#
#
# </head>
# <body data-logged-in="false" data-pageid="386" class="fsHasHeader fsHasLeftBanner fsHasMenu fsHasFooter fsHasOneColumnLayout fsSection154 fsHasTheme2">
#
# <script>
# dataLayer = [{ 'schoolDomain': 'www.oes.edu' }];
# dataLayer.push({'uaID': 'UA-5136820-1' });
#
# </script>
#
# <noscript>
# <iframe src="//www.googletagmanager.com/ns.html?id=GTM-P3BGC7"
# height="0" width="0" style="display:none;visibility:hidden">
# </iframe>
# </noscript>
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P3BGC7');
# </script>
#
#
# <div id="fsPageWrapper">
#
#
#
# <div id="fsMenu">
# <div class=" fsMenu fsStyleAutoclear" id="fsEl_493" >
#
# <div class="fsElement fsContent close-button-container" id="fsEl_920" >
#
# <div class="fsElementContent">
# <button class="drawer-trigger" href="#"></button>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_494" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li class="fsNavParentPage"><a href="/aboutoes/leadership">Leadership</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/leadership/board-of-trustees">Board of Trustees Information</a></li></ul></div></li><li class="fsNavParentPage"><a href="/aboutoes/strategic-plan">Strategic Plan</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/strategic-plan/program">Program</a></li><li><a href="/aboutoes/strategic-plan/people">People</a></li><li><a href="/aboutoes/strategic-plan/place">Place</a></li><li><a href="/aboutoes/strategic-plan/plan">Plan</a></li></ul></div></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li class="fsNavParentPage"><a href="/aboutoes/community-partnerships">Community Partnerships</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/community-partnerships/aardvarks-advocate-for-skills-knowledge-aask">Aardvarks Advocate for Skills &amp; Knowledge (AASK)</a></li><li><a href="/aboutoes/community-partnerships/community-conversations">Community Conversations</a></li><li><a href="/aboutoes/community-partnerships/spring-event">Spring Event</a></li></ul></div></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/admissions/inquire">Inquire</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/inquire/admissionsfaqs">Admissions FAQs</a></li><li><a href="/admissions/inquire/parent-tours">Parent Tours</a></li><li><a href="/admissions/inquire/student-visits">Student Visits</a></li><li><a href="/admissions/inquire/open-house">Open House</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/application-process">Application Process</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/application-process/ssat">SSAT</a></li><li><a href="/admissions/application-process/toefl">TOEFL</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/tuition-financial-aid/financial-aid-faqs">Financial Aid FAQs</a></li><li><a href="/admissions/tuition-financial-aid/faapplication">Financial Aid Application</a></li></ul></div></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/academics/academic-curriculum">Academic Curriculum</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/academics/academic-curriculum/our-approach">Our Approach</a></li><li class="fsNavParentPage"><a href="/academics/academic-curriculum/arts">Arts</a><div class="fsNavPageInfo"><ul class="fsNavLevel4"><li><a hr ...
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_1070" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li><a href="/contact-us">Contact Us</a></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_1071" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
#
# <header id="fsHeader" class="fsHeader">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_7" >
#
# <div class="fsElement fsContent logo-container" id="fsEl_69" >
#
# <div class="fsElementContent">
# <a href="/"><img alt="Oregon Episcopal School - ALWAYS OPEN" width="134" src="/uploaded/themes/default2016-redesign/images/logo.jpg"></a>
#
# </div>
#
#
# </div>
# <div class="fsElement fsContainer site-info-container" id="fsEl_921" >
#
# <div class="fsElementContent">
# <div class="fsElement fsContainer nav-holder" id="fsEl_922" >
#
# <div class="fsElementContent">
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_923" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_924" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li class="fsNavParentPage"><a href="/contact-us">Contact Us</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/contact-us/faculty-staff-directory">Employee Directory</a></li><li><a href="/contact-us/directions">Directions to Campus</a></li></ul></div></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsSearch site-search fsSearchField" id="fsEl_942" data-use-new="true">
#
# <div class="fsElementContent">
#
# <script>
# (function() {
# var scriptCoreId = 'fsSearchElementScriptCore';
#
# if(document.getElementById(scriptCoreId) == null) {
# var cx = '003863166793472101546:franr--wiru';
# var gcse = document.createElement('script');
# gcse.type = 'text/javascript';
# gcse.async = true;
# gcse.src = '//www.google.com/cse/cse.js?cx=' + cx;
# gcse.id = scriptCoreId;
# var s = document.getElementsByTagName('script')[0];
# s.parentNode.insertBefore(gcse, s);
#
# $(function() {
# // The search button is created by google's asynchronously loaded code after rendering and even after $(document).ready().
# // Likewise, the $(gcse).load() event also fires before the DOM elements we need to change are rendered.
# // We need to add an observer to find out when it's actually added so that we can adjust accordingly
# var observer = new MutationObserver(function() {
# $('input.gsc-search-button').attr('alt', 'Submit Search')
# });
# $('.gcse-searchbox-only').each(function() {
# observer.observe(this.parentNode, {childList: true, subtree: true});
# });
# });
# }
# })();
# </script>
#
# <div class="gcse-searchbox-only" data-as_sitesearch="www.oes.edu" data-resultsUrl="/search-results"></div>
#
#
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_925" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li><a href="/aboutoes/leadership">Leadership</a></li><li><a href="/aboutoes/strategic-plan">Strategic Plan</a></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li><a href="/aboutoes/community-partnerships">Community Partnerships</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/admissions/inquire">Inquire</a></li><li><a href="/admissions/application-process">Application Process</a></li><li><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/academics/academic-curriculum">Academic Curriculum</a></li><li><a href="/academics/lower-school">Lower School Home</a></li><li><a href="/academics/middle-school">Middle School Home</a></li><li class="fsNavCurrentPageAncestor"><a href="/academics/upper-school">Upper School Home</a></li><li><a href="/academics/libraries">Libraries</a></li></ul></div></li><li class="fsNavParentPage"><a href="/athletics">ATHLETICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/athletics/home-of-the-aardvarks">Home of the Aardvarks</a></li><li><a href="/athletics/full-athletic-calendar">Full Athletic Calendar</a></li><li><a href="/athletics/athletic-teams">Athletic Teams</a></li><li><a href="/athletics/ad-blog">Athletic Director's Blog</a></li><li><a href="/athletics/faqs">FAQs</a></li><li><a href="/athletics/concussion-protocol">Concussion Protocol</a></li><li><a href="/athletics/athletic-staff-coaches">Athletic Staff &amp; Head Coaches</a></li></ul></div></li><li class="fsNavParentPage"><a href="/student-life">STUDENT LIFE</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/student-life/service-learning">Service Learning</a></li><li><a href="/student-life/extension">Extension</a></li><li><a href="/student-life/experiential-education">Experiential Education</a></li><li><a href="/student-life/spiritual-growth">Spiritual Growth</a></li><li><a href="/student-life/health-well-being">Health &amp; Well Being</a></li><li><a href="/student-life/gathering">Gathering</a></li></ul></div></li><li class="fsNavParentPage"><a href="/support-oes">SUPPORT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/support-oes/giving-matters">Why Giving Matters</a></li><li><a href="/support-oes/annual-giving">Annual Giving</a></li><li><a href="/support-oes/endowed-funds">Endowed Funds</a></li><li><a href="http://oes.giftplans.org/">Gift Planning</a></li><li><a href="/support-oes/faq">FAQs</a></li><li><a href="/support-oes/meet-the-team">Meet the Team</a></li><li><a href="/support-oes/make-your-gift">Make Your Gift</a></li></ul></div></li><li class="fsNavParentPage"><a href="/news">NEW ...
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </header>
#
# <div id="fsPageBodyWrapper" class="fsPageBodyWrapper">
# <div id="fsPageBody" class="fsStyleAutoclear fsPageBody">
#
# <div id="fsBannerLeft" class="fsBannerLeft">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_8" >
#
# <div class="fsElement fsNavigation fsList nav-sub" id="fsEl_44" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/academics/academic-curriculum">Academic Curriculum</a></li><li><a href="/academics/lower-school">Lower School Home</a></li><li><a href="/academics/middle-school">Middle School Home</a></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics/upper-school">Upper School Home</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/academics/upper-school/academics">Academics</a></li><li><a href="/academics/upper-school/co-curriculum">Co-Curriculum</a></li><li><a href="/academics/academic-curriculum/arts">Arts</a></li><li><a href="/academics/upper-school/counseling-academic-support">Counseling &amp; Academic Support</a></li><li><a href="/academics/upper-school/college-counseling">College Counseling</a></li><li class="fsNavCurrentPage"><a href="/academics/upper-school/faculty-staff">Upper School Faculty &amp; Staff</a></li><li><a href="/academics/upper-school/voice-newsletter">Voice Newsletter</a></li></ul></div></li><li><a href="/academics/libraries">Libraries</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <main id="fsPageContent" class="fsPageContent">
# <h1 class="fsPageTitle">Upper School Faculty &amp; Staff</h1>
#
#
#
#
# <div class="fsPageLayout fsLayout fsOneColumnLayout fsStyleAutoclear" id="fsEl_2480" >
#
# <div class=" fsDiv fsStyleAutoclear" id="fsEl_2481" >
#
# <div class="fsElement fsConstituent fsSearch fsThumbnailOriginal fsThumbnailSmall" id="fsEl_3624" >
#
# <div class="fsElementContent">
# <form class="fsConstituentSearchForm" action="/academics/upper-school/faculty-staff" accept-charset="UTF-8" method="get"><input name="utf8" type="hidden" value="&#x2713;" />
# <input type="hidden" name="const_search_group_ids" value="131">
# <input type="hidden" name="const_search_role_ids" value="1">
#
# <label>
# <span>Keyword</span>
# <input type="text" name="const_search_keyword" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
#
# <label>
# <span>First Name</span>
# <input type="text" name="const_search_first_name" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
# <label>
# <span>Last Name</span>
# <input type="text" name="const_search_last_name" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
#
#
#
# <label>
# <span>Department</span>
# <select name="const_search_department">
# <option value="">All Departments</option>
# <option value="265">AASK</option>
# <option value="245">Administration</option>
# <option value="239">Athletics</option>
# <option value="266">Basketball</option>
# <option value="246">Chaplaincy</option>
# <option value="247">College Counseling</option>
# <option value="263">Community Partnerships</option>
# <option value="270">Counseling</option>
# <option value="261">Cross Country</option>
# <option value="232">Dorms</option>
# <option value="260">ELS</option>
# <option value="235">English</option>
# <option value="257">Experiential Education</option>
# <option value="243">Extension</option>
# <option value="268">Golf</option>
# <option value="255">History</option>
# <option value="225">Information Technology</option>
# <option value="269">Lacrosse</option>
# <option value="283">Librarians-Head</option>
# <option value="252">Library</option>
# <option value="244">Mathematics</option>
# <option value="240">Music</option>
# <option value="279">Nurse &amp; Athletic Trainer</option>
# <option value="237">Physical Education</option>
# <option value="253">Private Lessons</option>
# <option value="259">Religion &amp; Philosophy</option>
# <option value="249">Science</option>
# <option value="256">Service Learning</option>
# <option value="273">Skiing</option>
# <option value="267">Soccer</option>
# <option value="236">Student Support</option>
# <option value="250">Tennis</option>
# <option value="254">Track &amp; Field</option>
# <option value="231">Upper School Administration</option>
# <option value="278">US Counseling &amp; Academic Support</option>
# <option value="241">Visual &amp; Performing Arts (VaPA)</option>
# <option value="271">Volleyball</option>
# <option value="227">World Languages</option>
# </select>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <input type="submit" class="fsConstituentSearchButton fsStyleUpdateButton" value="Search Directory">
# </form>
# </div>
#
#
# </div>
# <div class="fsElement fsConstituent fsDirectory fsThumbnailOriginal fsThumbnailLarge" id="fsEl_3623" >
#
# <div class="fsElementContent">
#
# <div class="fsElementPagination" data-searchparams="{}">
#
#
#
# <a href="?const_page=1&amp;" data-page="1" class="fsFirstPageLink" disabled="disabled">1</a>
#
#
#
#
# <a href="?const_page=2&amp;" data-page="2">2</a>
# <a href="?const_page=3&amp;" data-page="3">3</a>
# <a href="?const_page=5&amp;" data-page="5">&hellip;</a>
#
# <a href="?const_page=6&amp;" data-page="6" class="fsLastPageLink">6</a>
#
# <a href="?const_page=2&amp;" data-page="2" data-searchparams="{}" class="fsNextPageLink">&gt;</a>
#
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>
#
# <div class="fsConstituentColumnLayout_3 fsStyleAutoclear">
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Deri Bash " src="/uploaded/New_Site/Employee_Directory/Deri_Bash.jpg" /></div>
#
# <h3 class="fsFullName">
# Deri Bash
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Associate Head of Upper School for Academics & Residential Life
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Upper School Administration, Dorms
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2478-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2478-directory", "ude.seo", "dhsab", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9357">
# 503-416-9357
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Brad Baugher " src="/uploaded/New_Site/Employee_Directory/Brad_Baugher.jpg" /></div>
#
# <h3 class="fsFullName">
# Brad Baugher
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Director of Educational Technology
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Information Technology
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2480-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2480-directory", "ude.seo", "brehguab", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3136">
# 503-768-3136
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Carmen Boyle " src="/uploaded/New_Site/Employee_Directory/Carmen_Boyle.jpg" /></div>
#
# <h3 class="fsFullName">
# Carmen Boyle
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Spanish Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2488-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2488-directory", "ude.seo", "celyob", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9238">
# 503-416-9238
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Peter Buonincontro " src="/uploaded/New_Site/Employee_Directory/Peter_Buonincontro.jpg" /></div>
#
# <h3 class="fsFullName">
# Peter Buonincontro
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Residential House Head, Theater & Performing Arts Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Dorms, Visual & Performing Arts (VaPA)
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2493-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2493-directory", "ude.seo", "portnocninoub", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3171">
# 503-768-3171
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Eduard Cecere " src="/uploaded/New_Site/Employee_Directory/Eduardo_Cecere.jpg" /></div>
#
# <h3 class="fsFullName">
# Eduard Cecere
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Upper School Technology Coordinator
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Information Technology
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2497-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2497-directory", "ude.seo", "eerecec", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9354">
# 503-416-9354
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Dennis Chang " src="/uploaded/New_Site/Employee_Directory/Dennis_Chang.jpg" /></div>
#
# <h3 class="fsFullName">
# Dennis Chang
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Algebra Teacher, Head JV Girls' Soccer Coach
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Athletics, Mathematics
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2499-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2499-directory", "ude.seo", "dgnahc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9289">
# 503-416-9289
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Chiman Chen " src="/uploaded/New_Site/Employee_Directory/Chiman_Chen.jpg" /></div>
#
# <h3 class="fsFullName">
# Chiman Chen
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Mandarin Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2500-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2500-directory", "ude.seo", "cnehc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9267">
# 503-416-9267
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Corbet Clark " src="/uploaded/New_Site/Employee_Directory/Corbet_Clark.jpg" /></div>
#
# <h3 class="fsFullName">
# Corbet Clark
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Interim Head of Upper School
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Upper School Administration, Administration
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2501-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2501-directory", "ude.seo", "ckralc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3121">
# 503-768-3121
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Jenny Cleveland " src="/uploaded/New_Site/Employee_Directory/Jenny_Cleveland.jpg" /></div>
#
# <h3 class="fsFullName">
# Jenny Cleveland
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Chaplain, College Counselor
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Chaplaincy, College Counseling
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2504-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2504-directory", "ude.seo", "jdnalevelc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9242">
# 503-416-9242
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Bevin Daglen " src="/uploaded/New_Site/Employee_Directory/Bevin_Daglen.jpg" /></div>
#
# <h3 class="fsFullName">
# Bevin Daglen
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Science Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Science
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2508-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2508-directory", "ude.seo", "bnelgad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9320">
# 503-416-9320
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Tessa Daniel " src="/uploaded/New_Site/Employee_Directory/Tessa_Daniel.jpg" /></div>
#
# <h3 class="fsFullName">
# Tessa Daniel
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Spanish Teacher, Yearbook
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2510-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2510-directory", "ude.seo", "tleinad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9297">
# 503-416-9297
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Coleen Davis " src="/uploaded/New_Site/Employee_Directory/Coleen_Davis.jpg" /></div>
#
# <h3 class="fsFullName">
# Coleen Davis
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Physical Education Teacher, Head Girls' Tennis Coach, SPARC Manager
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Physical Education, Athletics, Tennis
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2511-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2511-directory", "ude.seo", "csivad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3175">
# 503-768-3175
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
# </div>
# <div class="fsElementPagination" data-searchparams="{}">
#
#
#
# <a href="?const_page=1&amp;" data-page="1" class="fsFirstPageLink" disabled="disabled">1</a>
#
#
#
#
# <a href="?const_page=2&amp;" data-page="2">2</a>
# <a href="?const_page=3&amp;" data-page="3">3</a>
# <a href="?const_page=5&amp;" data-page="5">&hellip;</a>
#
# <a href="?const_page=6&amp;" data-page="6" class="fsLastPageLink">6</a>
#
# <a href="?const_page=2&amp;" data-page="2" data-searchparams="{}" class="fsNextPageLink">&gt;</a>
#
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>
#
#
# </div>
#
#
# </div>
#
#
#
#
# </div>
#
#
#
#
# </div>
#
#
#
# </main>
# </div>
# </div>
#
# <footer id="fsFooter" class="fsFooter">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_9" >
#
# <div class="fsElement fsContainer address-utility" id="fsEl_946" >
#
# <div class="fsElementContent">
# <div class="fsElement fsContent" id="fsEl_947" >
#
# <div class="fsElementContent">
# <div itemtype="http://schema.org/EducationalOrganization" class="school-details">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
# <span itemprop="addressRegion">OR</span>,
# <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-footer" id="fsEl_948" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <div class="fsElement fsContent tagline" id="fsEl_949" >
#
# <div class="fsElementContent">
# <p></p><p>Oregon Episcopal School is a college preparatory, independent school in Portland, Oregon, serving 860 students from Pre-Kindergarten through Grade 12, including 60 boarding students from around the world in Grades 9-12.</p><p></p>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-social" id="fsEl_950" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://www.facebook.com/oregon.episcopal" target="_blank">Facebook</a></li><li><a href="http://twitter.com/oregonepiscopal" target="_blank">Twitter</a></li><li><a href="http://www.youtube.com/user/OESTV" target="_blank">Youtube</a></li><li><a href="https://instagram.com/oregonepiscopal" target="_blank">Instagram</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
#
#
# </div>
#
#
# </footer>
#
# <div id="fsPoweredByFinalsite">
# <div>
# <a href="http://www.finalsite.com" target="_blank">Powered by Finalsite</a>
# </div>
# </div>
#
#
#
# </div>
#
#
#
#
#
# <script src="//static.finalsite.net/assets/application-8ee0832aea95b0177619c7a0f1966aadcab36725af74a145f58c313cec8abc6b.js"></script>
#
# <script src="/uploaded/themes/default2016-redesign/js/main.js?1490386593"></script>
#
#
#
#
#
# </body></html>

# %% [markdown]
# Let's try printing out just the h3 info using BeautifulSoup:

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff').read()

soup = BeautifulSoup(fhand, "html.parser")

headers = soup('h3')
print(headers)
# Out:
# [<h3 class="fsFullName">
# 				Deri Bash
# 		</h3>, <h3 class="fsFullName">
# 				Brad Baugher
# 		</h3>, <h3 class="fsFullName">
# 				Carmen Boyle
# 		</h3>, <h3 class="fsFullName">
# 				Peter Buonincontro
# 		</h3>, <h3 class="fsFullName">
# 				Eduard Cecere
# 		</h3>, <h3 class="fsFullName">
# 				Dennis Chang
# 		</h3>, <h3 class="fsFullName">
# 				Chiman Chen
# 		</h3>, <h3 class="fsFullName">
# 				Corbet Clark
# 		</h3>, <h3 class="fsFullName">
# 				Jenny Cleveland
# 		</h3>, <h3 class="fsFullName">
# 				Bevin Daglen
# 		</h3>, <h3 class="fsFullName">
# 				Tessa Daniel
# 		</h3>, <h3 class="fsFullName">
# 				Coleen Davis
# 		</h3>]

# %% [markdown]
# That's still not quite as pretty as we'd like, but remember that there are multiple attributes stored in the headers. In this case, we want to access its contents:

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff').read()

soup = BeautifulSoup(fhand, "html.parser")

headers = soup('h3')
for header in headers:
    print(header.contents[0].strip())
# Out:
# Deri Bash
# Brad Baugher
# Carmen Boyle
# Peter Buonincontro
# Eduard Cecere
# Dennis Chang
# Chiman Chen
# Corbet Clark
# Jenny Cleveland
# Bevin Daglen
# Tessa Daniel
# Coleen Davis

# %% [markdown]
# Notice that by using BeautifulSoup, we didn't need to create a loop to search for "Full Name."

# %% [markdown]
# Suppose we wanted to get what department each faculty member works in. First we notice that their departments are inside "div class":

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff')
for line in fhand:
    print(line.decode().strip())
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 8]>         <html lang="en-US" class="lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8">
#
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"87d38be11c","applicationID":"11580779","transactionName":"JVgLEhBaXg4BSxgTWQFSFkkKVFwGCFxoEFQTUA==","queueTime":0,"applicationTime":532,"agent":""}</script>
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"UwMPVVVUGwIBUVlSAAYO"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,n,e)])}catch(s){try{i("ierr",[s,c.now(),!0])}catch(u){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t){i("err",[t,c.now()])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=window.onerror,u=!1,d=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),u=!0)}s.on("fn-start",function(t,n,e){u&&(d+=1)}),s.on("fn-err",function(t,n,e){u&&(this.thrown=!0,o(e))}),s.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pus ...
# <title>Upper School Faculty &amp; Staff - OES</title>
# <link rel="icon" href="/uploaded/favicon.ico">
# <meta name="description" content="Upper School Faculty &amp; Staff - Oregon Episcopal School">
# <meta name="keywords" content="Upper School Faculty &amp; Staff, Oregon Episcopal School">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <link rel="canonical" href="https://www.oes.edu/academics/upper-school/faculty-staff">
# <meta property="og:url" content="https://www.oes.edu/academics/upper-school/faculty-staff">
# <meta property="og:description" content="Upper School Faculty &amp; Staff - Oregon Episcopal School">
# <meta property="og:title" content="Upper School Faculty &amp; Staff - OES">
# <meta property="og:type" content="website">
#
# <link rel="stylesheet" media="all" href="//static.finalsite.net/assets/application-576e2437b540b042b53dc059e8b146681fd3f4a6ca48a4166f1cf620fd626e82.css" />
#
#
#
# <!-- CF Styles Manager -->
# <link href="/styles.cfm?b" media="screen" rel="stylesheet">
#
# <link rel="stylesheet" media="all" href="/uploaded/themes/default2016-redesign/css/main.css?1490386593" />
#
# <script src="//static.finalsite.net/assets/in_layout_head-6e205639bc9a6ac0ef6b96704a4ad11c0a47a98dbdc16c0e42189cbd7a8402b7.js"></script>
#
# <script src="https://use.typekit.net/umt8nlk.js"></script>
# <script>try{Typekit.load({ async: true });}catch(e){}</script>
#
# <meta name="google-site-verification" content="ChHbB0fSWOrmC_rvlv-ldZNRVyXhPVC2Sxmi4RszbDo" />
#
#
# <script type="text/javascript">
# (function(window) {
# window.FS.currentPage = {
# dateFormat: 'md',
# timeFormat: '12'
# }
# })(window);
# </script>
#
#
# </head>
# <body data-logged-in="false" data-pageid="386" class="fsHasHeader fsHasLeftBanner fsHasMenu fsHasFooter fsHasOneColumnLayout fsSection154 fsHasTheme2">
#
# <script>
# dataLayer = [{ 'schoolDomain': 'www.oes.edu' }];
# dataLayer.push({'uaID': 'UA-5136820-1' });
#
# </script>
#
# <noscript>
# <iframe src="//www.googletagmanager.com/ns.html?id=GTM-P3BGC7"
# height="0" width="0" style="display:none;visibility:hidden">
# </iframe>
# </noscript>
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P3BGC7');
# </script>
#
#
# <div id="fsPageWrapper">
#
#
#
# <div id="fsMenu">
# <div class=" fsMenu fsStyleAutoclear" id="fsEl_493" >
#
# <div class="fsElement fsContent close-button-container" id="fsEl_920" >
#
# <div class="fsElementContent">
# <button class="drawer-trigger" href="#"></button>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_494" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li class="fsNavParentPage"><a href="/aboutoes/leadership">Leadership</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/leadership/board-of-trustees">Board of Trustees Information</a></li></ul></div></li><li class="fsNavParentPage"><a href="/aboutoes/strategic-plan">Strategic Plan</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/strategic-plan/program">Program</a></li><li><a href="/aboutoes/strategic-plan/people">People</a></li><li><a href="/aboutoes/strategic-plan/place">Place</a></li><li><a href="/aboutoes/strategic-plan/plan">Plan</a></li></ul></div></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li class="fsNavParentPage"><a href="/aboutoes/community-partnerships">Community Partnerships</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/community-partnerships/aardvarks-advocate-for-skills-knowledge-aask">Aardvarks Advocate for Skills &amp; Knowledge (AASK)</a></li><li><a href="/aboutoes/community-partnerships/community-conversations">Community Conversations</a></li><li><a href="/aboutoes/community-partnerships/spring-event">Spring Event</a></li></ul></div></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/admissions/inquire">Inquire</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/inquire/admissionsfaqs">Admissions FAQs</a></li><li><a href="/admissions/inquire/parent-tours">Parent Tours</a></li><li><a href="/admissions/inquire/student-visits">Student Visits</a></li><li><a href="/admissions/inquire/open-house">Open House</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/application-process">Application Process</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/application-process/ssat">SSAT</a></li><li><a href="/admissions/application-process/toefl">TOEFL</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/tuition-financial-aid/financial-aid-faqs">Financial Aid FAQs</a></li><li><a href="/admissions/tuition-financial-aid/faapplication">Financial Aid Application</a></li></ul></div></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/academics/academic-curriculum">Academic Curriculum</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/academics/academic-curriculum/our-approach">Our Approach</a></li><li class="fsNavParentPage"><a href="/academics/academic-curriculum/arts">Arts</a><div class="fsNavPageInfo"><ul class="fsNavLevel4"><li><a hr ...
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_1070" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li><a href="/contact-us">Contact Us</a></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_1071" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
#
# <header id="fsHeader" class="fsHeader">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_7" >
#
# <div class="fsElement fsContent logo-container" id="fsEl_69" >
#
# <div class="fsElementContent">
# <a href="/"><img alt="Oregon Episcopal School - ALWAYS OPEN" width="134" src="/uploaded/themes/default2016-redesign/images/logo.jpg"></a>
#
# </div>
#
#
# </div>
# <div class="fsElement fsContainer site-info-container" id="fsEl_921" >
#
# <div class="fsElementContent">
# <div class="fsElement fsContainer nav-holder" id="fsEl_922" >
#
# <div class="fsElementContent">
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_923" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_924" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li class="fsNavParentPage"><a href="/contact-us">Contact Us</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/contact-us/faculty-staff-directory">Employee Directory</a></li><li><a href="/contact-us/directions">Directions to Campus</a></li></ul></div></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
#
#
# </div>
# <div class="fsElement fsSearch site-search fsSearchField" id="fsEl_942" data-use-new="true">
#
# <div class="fsElementContent">
#
# <script>
# (function() {
# var scriptCoreId = 'fsSearchElementScriptCore';
#
# if(document.getElementById(scriptCoreId) == null) {
# var cx = '003863166793472101546:franr--wiru';
# var gcse = document.createElement('script');
# gcse.type = 'text/javascript';
# gcse.async = true;
# gcse.src = '//www.google.com/cse/cse.js?cx=' + cx;
# gcse.id = scriptCoreId;
# var s = document.getElementsByTagName('script')[0];
# s.parentNode.insertBefore(gcse, s);
#
# $(function() {
# // The search button is created by google's asynchronously loaded code after rendering and even after $(document).ready().
# // Likewise, the $(gcse).load() event also fires before the DOM elements we need to change are rendered.
# // We need to add an observer to find out when it's actually added so that we can adjust accordingly
# var observer = new MutationObserver(function() {
# $('input.gsc-search-button').attr('alt', 'Submit Search')
# });
# $('.gcse-searchbox-only').each(function() {
# observer.observe(this.parentNode, {childList: true, subtree: true});
# });
# });
# }
# })();
# </script>
#
# <div class="gcse-searchbox-only" data-as_sitesearch="www.oes.edu" data-resultsUrl="/search-results"></div>
#
#
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_925" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li><a href="/aboutoes/leadership">Leadership</a></li><li><a href="/aboutoes/strategic-plan">Strategic Plan</a></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li><a href="/aboutoes/community-partnerships">Community Partnerships</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/admissions/inquire">Inquire</a></li><li><a href="/admissions/application-process">Application Process</a></li><li><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/academics/academic-curriculum">Academic Curriculum</a></li><li><a href="/academics/lower-school">Lower School Home</a></li><li><a href="/academics/middle-school">Middle School Home</a></li><li class="fsNavCurrentPageAncestor"><a href="/academics/upper-school">Upper School Home</a></li><li><a href="/academics/libraries">Libraries</a></li></ul></div></li><li class="fsNavParentPage"><a href="/athletics">ATHLETICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/athletics/home-of-the-aardvarks">Home of the Aardvarks</a></li><li><a href="/athletics/full-athletic-calendar">Full Athletic Calendar</a></li><li><a href="/athletics/athletic-teams">Athletic Teams</a></li><li><a href="/athletics/ad-blog">Athletic Director's Blog</a></li><li><a href="/athletics/faqs">FAQs</a></li><li><a href="/athletics/concussion-protocol">Concussion Protocol</a></li><li><a href="/athletics/athletic-staff-coaches">Athletic Staff &amp; Head Coaches</a></li></ul></div></li><li class="fsNavParentPage"><a href="/student-life">STUDENT LIFE</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/student-life/service-learning">Service Learning</a></li><li><a href="/student-life/extension">Extension</a></li><li><a href="/student-life/experiential-education">Experiential Education</a></li><li><a href="/student-life/spiritual-growth">Spiritual Growth</a></li><li><a href="/student-life/health-well-being">Health &amp; Well Being</a></li><li><a href="/student-life/gathering">Gathering</a></li></ul></div></li><li class="fsNavParentPage"><a href="/support-oes">SUPPORT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/support-oes/giving-matters">Why Giving Matters</a></li><li><a href="/support-oes/annual-giving">Annual Giving</a></li><li><a href="/support-oes/endowed-funds">Endowed Funds</a></li><li><a href="http://oes.giftplans.org/">Gift Planning</a></li><li><a href="/support-oes/faq">FAQs</a></li><li><a href="/support-oes/meet-the-team">Meet the Team</a></li><li><a href="/support-oes/make-your-gift">Make Your Gift</a></li></ul></div></li><li class="fsNavParentPage"><a href="/news">NEW ...
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </header>
#
# <div id="fsPageBodyWrapper" class="fsPageBodyWrapper">
# <div id="fsPageBody" class="fsStyleAutoclear fsPageBody">
#
# <div id="fsBannerLeft" class="fsBannerLeft">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_8" >
#
# <div class="fsElement fsNavigation fsList nav-sub" id="fsEl_44" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/academics/academic-curriculum">Academic Curriculum</a></li><li><a href="/academics/lower-school">Lower School Home</a></li><li><a href="/academics/middle-school">Middle School Home</a></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics/upper-school">Upper School Home</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/academics/upper-school/academics">Academics</a></li><li><a href="/academics/upper-school/co-curriculum">Co-Curriculum</a></li><li><a href="/academics/academic-curriculum/arts">Arts</a></li><li><a href="/academics/upper-school/counseling-academic-support">Counseling &amp; Academic Support</a></li><li><a href="/academics/upper-school/college-counseling">College Counseling</a></li><li class="fsNavCurrentPage"><a href="/academics/upper-school/faculty-staff">Upper School Faculty &amp; Staff</a></li><li><a href="/academics/upper-school/voice-newsletter">Voice Newsletter</a></li></ul></div></li><li><a href="/academics/libraries">Libraries</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <main id="fsPageContent" class="fsPageContent">
# <h1 class="fsPageTitle">Upper School Faculty &amp; Staff</h1>
#
#
#
#
# <div class="fsPageLayout fsLayout fsOneColumnLayout fsStyleAutoclear" id="fsEl_2480" >
#
# <div class=" fsDiv fsStyleAutoclear" id="fsEl_2481" >
#
# <div class="fsElement fsConstituent fsSearch fsThumbnailOriginal fsThumbnailSmall" id="fsEl_3624" >
#
# <div class="fsElementContent">
# <form class="fsConstituentSearchForm" action="/academics/upper-school/faculty-staff" accept-charset="UTF-8" method="get"><input name="utf8" type="hidden" value="&#x2713;" />
# <input type="hidden" name="const_search_group_ids" value="131">
# <input type="hidden" name="const_search_role_ids" value="1">
#
# <label>
# <span>Keyword</span>
# <input type="text" name="const_search_keyword" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
#
# <label>
# <span>First Name</span>
# <input type="text" name="const_search_first_name" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
# <label>
# <span>Last Name</span>
# <input type="text" name="const_search_last_name" class="fsConstituentSearchField fsStyleDefaultField" value="">
# </label>
#
#
#
#
# <label>
# <span>Department</span>
# <select name="const_search_department">
# <option value="">All Departments</option>
# <option value="265">AASK</option>
# <option value="245">Administration</option>
# <option value="239">Athletics</option>
# <option value="266">Basketball</option>
# <option value="246">Chaplaincy</option>
# <option value="247">College Counseling</option>
# <option value="263">Community Partnerships</option>
# <option value="270">Counseling</option>
# <option value="261">Cross Country</option>
# <option value="232">Dorms</option>
# <option value="260">ELS</option>
# <option value="235">English</option>
# <option value="257">Experiential Education</option>
# <option value="243">Extension</option>
# <option value="268">Golf</option>
# <option value="255">History</option>
# <option value="225">Information Technology</option>
# <option value="269">Lacrosse</option>
# <option value="283">Librarians-Head</option>
# <option value="252">Library</option>
# <option value="244">Mathematics</option>
# <option value="240">Music</option>
# <option value="279">Nurse &amp; Athletic Trainer</option>
# <option value="237">Physical Education</option>
# <option value="253">Private Lessons</option>
# <option value="259">Religion &amp; Philosophy</option>
# <option value="249">Science</option>
# <option value="256">Service Learning</option>
# <option value="273">Skiing</option>
# <option value="267">Soccer</option>
# <option value="236">Student Support</option>
# <option value="250">Tennis</option>
# <option value="254">Track &amp; Field</option>
# <option value="231">Upper School Administration</option>
# <option value="278">US Counseling &amp; Academic Support</option>
# <option value="241">Visual &amp; Performing Arts (VaPA)</option>
# <option value="271">Volleyball</option>
# <option value="227">World Languages</option>
# </select>
# </label>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <input type="submit" class="fsConstituentSearchButton fsStyleUpdateButton" value="Search Directory">
# </form>
# </div>
#
#
# </div>
# <div class="fsElement fsConstituent fsDirectory fsThumbnailOriginal fsThumbnailLarge" id="fsEl_3623" >
#
# <div class="fsElementContent">
#
# <div class="fsElementPagination" data-searchparams="{}">
#
#
#
# <a href="?const_page=1&amp;" data-page="1" class="fsFirstPageLink" disabled="disabled">1</a>
#
#
#
#
# <a href="?const_page=2&amp;" data-page="2">2</a>
# <a href="?const_page=3&amp;" data-page="3">3</a>
# <a href="?const_page=5&amp;" data-page="5">&hellip;</a>
#
# <a href="?const_page=6&amp;" data-page="6" class="fsLastPageLink">6</a>
#
# <a href="?const_page=2&amp;" data-page="2" data-searchparams="{}" class="fsNextPageLink">&gt;</a>
#
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>
#
# <div class="fsConstituentColumnLayout_3 fsStyleAutoclear">
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Deri Bash " src="/uploaded/New_Site/Employee_Directory/Deri_Bash.jpg" /></div>
#
# <h3 class="fsFullName">
# Deri Bash
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Associate Head of Upper School for Academics & Residential Life
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Upper School Administration, Dorms
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2478-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2478-directory", "ude.seo", "dhsab", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9357">
# 503-416-9357
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Brad Baugher " src="/uploaded/New_Site/Employee_Directory/Brad_Baugher.jpg" /></div>
#
# <h3 class="fsFullName">
# Brad Baugher
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Director of Educational Technology
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Information Technology
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2480-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2480-directory", "ude.seo", "brehguab", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3136">
# 503-768-3136
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Carmen Boyle " src="/uploaded/New_Site/Employee_Directory/Carmen_Boyle.jpg" /></div>
#
# <h3 class="fsFullName">
# Carmen Boyle
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Spanish Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2488-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2488-directory", "ude.seo", "celyob", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9238">
# 503-416-9238
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Peter Buonincontro " src="/uploaded/New_Site/Employee_Directory/Peter_Buonincontro.jpg" /></div>
#
# <h3 class="fsFullName">
# Peter Buonincontro
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Residential House Head, Theater & Performing Arts Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Dorms, Visual & Performing Arts (VaPA)
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2493-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2493-directory", "ude.seo", "portnocninoub", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3171">
# 503-768-3171
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Eduard Cecere " src="/uploaded/New_Site/Employee_Directory/Eduardo_Cecere.jpg" /></div>
#
# <h3 class="fsFullName">
# Eduard Cecere
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Upper School Technology Coordinator
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Information Technology
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2497-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2497-directory", "ude.seo", "eerecec", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9354">
# 503-416-9354
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Dennis Chang " src="/uploaded/New_Site/Employee_Directory/Dennis_Chang.jpg" /></div>
#
# <h3 class="fsFullName">
# Dennis Chang
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Algebra Teacher, Head JV Girls' Soccer Coach
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Athletics, Mathematics
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2499-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2499-directory", "ude.seo", "dgnahc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9289">
# 503-416-9289
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Chiman Chen " src="/uploaded/New_Site/Employee_Directory/Chiman_Chen.jpg" /></div>
#
# <h3 class="fsFullName">
# Chiman Chen
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Mandarin Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2500-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2500-directory", "ude.seo", "cnehc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9267">
# 503-416-9267
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Corbet Clark " src="/uploaded/New_Site/Employee_Directory/Corbet_Clark.jpg" /></div>
#
# <h3 class="fsFullName">
# Corbet Clark
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Interim Head of Upper School
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Upper School Administration, Administration
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2501-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2501-directory", "ude.seo", "ckralc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3121">
# 503-768-3121
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Jenny Cleveland " src="/uploaded/New_Site/Employee_Directory/Jenny_Cleveland.jpg" /></div>
#
# <h3 class="fsFullName">
# Jenny Cleveland
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Chaplain, College Counselor
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Chaplaincy, College Counseling
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2504-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2504-directory", "ude.seo", "jdnalevelc", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9242">
# 503-416-9242
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Bevin Daglen " src="/uploaded/New_Site/Employee_Directory/Bevin_Daglen.jpg" /></div>
#
# <h3 class="fsFullName">
# Bevin Daglen
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Science Teacher
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Science
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2508-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2508-directory", "ude.seo", "bnelgad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9320">
# 503-416-9320
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Tessa Daniel " src="/uploaded/New_Site/Employee_Directory/Tessa_Daniel.jpg" /></div>
#
# <h3 class="fsFullName">
# Tessa Daniel
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Spanish Teacher, Yearbook
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# World Languages
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2510-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2510-directory", "ude.seo", "tleinad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-416-9297">
# 503-416-9297
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
#
#
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img class="fsThumbnail" alt="Coleen Davis " src="/uploaded/New_Site/Employee_Directory/Coleen_Davis.jpg" /></div>
#
# <h3 class="fsFullName">
# Coleen Davis
# </h3>
#
#
#
#
# <div class="fsTitles">
# <strong>Titles:</strong>
# Physical Education Teacher, Head Girls' Tennis Coach, SPARC Manager
# </div>
#
#
#
#
#
#
#
# <div class="fsDepartments">
# <strong>Departments:</strong>
# Physical Education, Athletics, Tennis
# </div>
#
#
#
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2511-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2511-directory", "ude.seo", "csivad", false); }, 20);</script>
# </div>
# </div>
#
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# School:
# <a href="tel:503-768-3175">
# 503-768-3175
# </a><br>
# </div>
#
#
#
#
#
#
#
#
#
#
# </div>
#
# </div>
# <div class="fsElementPagination" data-searchparams="{}">
#
#
#
# <a href="?const_page=1&amp;" data-page="1" class="fsFirstPageLink" disabled="disabled">1</a>
#
#
#
#
# <a href="?const_page=2&amp;" data-page="2">2</a>
# <a href="?const_page=3&amp;" data-page="3">3</a>
# <a href="?const_page=5&amp;" data-page="5">&hellip;</a>
#
# <a href="?const_page=6&amp;" data-page="6" class="fsLastPageLink">6</a>
#
# <a href="?const_page=2&amp;" data-page="2" data-searchparams="{}" class="fsNextPageLink">&gt;</a>
#
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>
#
#
# </div>
#
#
# </div>
#
#
#
#
# </div>
#
#
#
#
# </div>
#
#
#
# </main>
# </div>
# </div>
#
# <footer id="fsFooter" class="fsFooter">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_9" >
#
# <div class="fsElement fsContainer address-utility" id="fsEl_946" >
#
# <div class="fsElementContent">
# <div class="fsElement fsContent" id="fsEl_947" >
#
# <div class="fsElementContent">
# <div itemtype="http://schema.org/EducationalOrganization" class="school-details">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
# <span itemprop="addressRegion">OR</span>,
# <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-util-footer" id="fsEl_948" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
# </div>
#
#
# </div>
# <div class="fsElement fsContent tagline" id="fsEl_949" >
#
# <div class="fsElementContent">
# <p></p><p>Oregon Episcopal School is a college preparatory, independent school in Portland, Oregon, serving 860 students from Pre-Kindergarten through Grade 12, including 60 boarding students from around the world in Grades 9-12.</p><p></p>
#
# </div>
#
#
# </div>
# <div class="fsElement fsNavigation fsList nav-social" id="fsEl_950" >
#
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://www.facebook.com/oregon.episcopal" target="_blank">Facebook</a></li><li><a href="http://twitter.com/oregonepiscopal" target="_blank">Twitter</a></li><li><a href="http://www.youtube.com/user/OESTV" target="_blank">Youtube</a></li><li><a href="https://instagram.com/oregonepiscopal" target="_blank">Instagram</a></li></ul></nav>
# </div>
#
#
# </div>
#
#
#
#
#
# </div>
#
#
# </footer>
#
# <div id="fsPoweredByFinalsite">
# <div>
# <a href="http://www.finalsite.com" target="_blank">Powered by Finalsite</a>
# </div>
# </div>
#
#
#
# </div>
#
#
#
#
#
# <script src="//static.finalsite.net/assets/application-8ee0832aea95b0177619c7a0f1966aadcab36725af74a145f58c313cec8abc6b.js"></script>
#
# <script src="/uploaded/themes/default2016-redesign/js/main.js?1490386593"></script>
#
#
#
#
#
# </body></html>

# %% [markdown]
# Let's first try printing out all of the tags labeled "div":

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff').read()
soup = BeautifulSoup(fhand, "html.parser")

divs = soup('div')
print(divs)
# Out:
# [<div id="fsPageWrapper">
# <div id="fsMenu">
# <div class=" fsMenu fsStyleAutoclear" id="fsEl_493">
# <div class="fsElement fsContent close-button-container" id="fsEl_920">
# <div class="fsElementContent">
# <button class="drawer-trigger" href="#"></button>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_494">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li class="fsNavParentPage"><a href="/aboutoes/leadership">Leadership</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/leadership/board-of-trustees">Board of Trustees Information</a></li></ul></div></li><li class="fsNavParentPage"><a href="/aboutoes/strategic-plan">Strategic Plan</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/strategic-plan/program">Program</a></li><li><a href="/aboutoes/strategic-plan/people">People</a></li><li><a href="/aboutoes/strategic-plan/place">Place</a></li><li><a href="/aboutoes/strategic-plan/plan">Plan</a></li></ul></div></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li class="fsNavParentPage"><a href="/aboutoes/community-partnerships">Community Partnerships</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/community-partnerships/aardvarks-advocate-for-skills-knowledge-aask">Aardvarks Advocate for Skills &amp; Knowledge (AASK)</a></li><li><a href="/aboutoes/community-partnerships/community-conversations">Community Conversations</a></li><li><a href="/aboutoes/community-partnerships/spring-event">Spring Event</a></li></ul></div></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/admissions/inquire">Inquire</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/inquire/admissionsfaqs">Admissions FAQs</a></li><li><a href="/admissions/inquire/parent-tours">Parent Tours</a></li><li><a href="/admissions/inquire/student-visits">Student Visits</a></li><li><a href="/admissions/inquire/open-house">Open House</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/application-process">Application Process</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/application-process/ssat">SSAT</a></li><li><a href="/admissions/application-process/toefl">TOEFL</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/tuition-financial-aid/financial-aid-faqs">Financial Aid FAQs</a></li><li><a href="/admissions/tuition-financial-aid/faapplication">Financial Aid Application</a></li></ul></div></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/academics/academic-curriculum">Academic Curriculum</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/academics/academic-curriculum/our-approach">Our Approach</a></li><li class="fsNavParentPage"><a href="/academics/academic-curriculum/arts">Arts</a><div class="fsNavPageInfo"><ul class="fsNavLevel4"><li><a hr ...
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_1070">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li><a href="/contact-us">Contact Us</a></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_1071">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
# </div>
# </div>
# </div>
# <header class="fsHeader" id="fsHeader">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_7">
# <div class="fsElement fsContent logo-container" id="fsEl_69">
# <div class="fsElementContent">
# <a href="/"><img alt="Oregon Episcopal School - ALWAYS OPEN" src="/uploaded/themes/default2016-redesign/images/logo.jpg" width="134"/></a>
# </div>
# </div>
# <div class="fsElement fsContainer site-info-container" id="fsEl_921">
# <div class="fsElementContent">
# <div class="fsElement fsContainer nav-holder" id="fsEl_922">
# <div class="fsElementContent">
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_923">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_924">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li class="fsNavParentPage"><a href="/contact-us">Contact Us</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/contact-us/faculty-staff-directory">Employee Directory</a></li><li><a href="/contact-us/directions">Directions to Campus</a></li></ul></div></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
# </div>
# <div class="fsElement fsSearch site-search fsSearchField" data-use-new="true" id="fsEl_942">
# <div class="fsElementContent">
# <script>
#     (function() {
#       var scriptCoreId = 'fsSearchElementScriptCore';
#
#       if(document.getElementById(scriptCoreId) == null) {
#         var cx = '003863166793472101546:franr--wiru';
#         var gcse = document.createElement('script');
#         gcse.type = 'text/javascript';
#         gcse.async = true;
#         gcse.src = '//www.google.com/cse/cse.js?cx=' + cx;
#         gcse.id = scriptCoreId;
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(gcse, s);
#
#         $(function() {
#             // The search button is created by google's asynchronously loaded code after rendering and even after $(document).ready().
#             // Likewise, the $(gcse).load() event also fires before the DOM elements we need to change are rendered.
#             // We need to add an observer to find out when it's actually added so that we can adjust accordingly
#             var observer = new MutationObserver(function() {
#                 $('input.gsc-search-button').attr('alt', 'Submit Search')
#             });
#             $('.gcse-searchbox-only').each(function() {
#                 observer.observe(this.parentNode, {childList: true, subtree: true});
#             });
#         });
#       }
#     })();
#   </script>
# <div class="gcse-searchbox-only" data-as_sitesearch="www.oes.edu" data-resultsurl="/search-results"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_925">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li><a href="/aboutoes/leadership">Leadership</a></li><li><a href="/aboutoes/strategic-plan">Strategic Plan</a></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li><a href="/aboutoes/community-partnerships">Community Partnerships</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/admissions/inquire">Inquire</a></li><li><a href="/admissions/application-process">Application Process</a></li><li><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/academics/academic-curriculum">Academic Curriculum</a></li><li><a href="/academics/lower-school">Lower School Home</a></li><li><a href="/academics/middle-school">Middle School Home</a></li><li class="fsNavCurrentPageAncestor"><a href="/academics/upper-school">Upper School Home</a></li><li><a href="/academics/libraries">Libraries</a></li></ul></div></li><li class="fsNavParentPage"><a href="/athletics">ATHLETICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/athletics/home-of-the-aardvarks">Home of the Aardvarks</a></li><li><a href="/athletics/full-athletic-calendar">Full Athletic Calendar</a></li><li><a href="/athletics/athletic-teams">Athletic Teams</a></li><li><a href="/athletics/ad-blog">Athletic Director's Blog</a></li><li><a href="/athletics/faqs">FAQs</a></li><li><a href="/athletics/concussion-protocol">Concussion Protocol</a></li><li><a href="/athletics/athletic-staff-coaches">Athletic Staff &amp; Head Coaches</a></li></ul></div></li><li class="fsNavParentPage"><a href="/student-life">STUDENT LIFE</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/student-life/service-learning">Service Learning</a></li><li><a href="/student-life/extension">Extension</a></li><li><a href="/student-life/experiential-education">Experiential Education</a></li><li><a href="/student-life/spiritual-growth">Spiritual Growth</a></li><li><a href="/student-life/health-well-being">Health &amp; Well Being</a></li><li><a href="/student-life/gathering">Gathering</a></li></ul></div></li><li class="fsNavParentPage"><a href="/support-oes">SUPPORT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/support-oes/giving-matters">Why Giving Matters</a></li><li><a href="/support-oes/annual-giving">Annual Giving</a></li><li><a href="/support-oes/endowed-funds">Endowed Funds</a></li><li><a href="http://oes.giftplans.org/">Gift Planning</a></li><li><a href="/support-oes/faq">FAQs</a></li><li><a href="/support-oes/meet-the-team">Meet the Team</a></li><li><a href="/support-oes/make-your-gift">Make Your Gift</a></li></ul></div></li><li class="fsNavParentPage"><a href="/news">NEW ...
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="fsPageBodyWrapper" id="fsPageBodyWrapper">
# <div class="fsStyleAutoclear fsPageBody" id="fsPageBody">
# <div class="fsBannerLeft" id="fsBannerLeft">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_8">
# <div class="fsElement fsNavigation fsList nav-sub" id="fsEl_44">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/academics/academic-curriculum">Academic Curriculum</a></li><li><a href="/academics/lower-school">Lower School Home</a></li><li><a href="/academics/middle-school">Middle School Home</a></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics/upper-school">Upper School Home</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/academics/upper-school/academics">Academics</a></li><li><a href="/academics/upper-school/co-curriculum">Co-Curriculum</a></li><li><a href="/academics/academic-curriculum/arts">Arts</a></li><li><a href="/academics/upper-school/counseling-academic-support">Counseling &amp; Academic Support</a></li><li><a href="/academics/upper-school/college-counseling">College Counseling</a></li><li class="fsNavCurrentPage"><a href="/academics/upper-school/faculty-staff">Upper School Faculty &amp; Staff</a></li><li><a href="/academics/upper-school/voice-newsletter">Voice Newsletter</a></li></ul></div></li><li><a href="/academics/libraries">Libraries</a></li></ul></nav>
# </div>
# </div>
# </div>
# </div>
# <main class="fsPageContent" id="fsPageContent">
# <h1 class="fsPageTitle">Upper School Faculty &amp; Staff</h1>
# <div class="fsPageLayout fsLayout fsOneColumnLayout fsStyleAutoclear" id="fsEl_2480">
# <div class=" fsDiv fsStyleAutoclear" id="fsEl_2481">
# <div class="fsElement fsConstituent fsSearch fsThumbnailOriginal fsThumbnailSmall" id="fsEl_3624">
# <div class="fsElementContent">
# <form accept-charset="UTF-8" action="/academics/upper-school/faculty-staff" class="fsConstituentSearchForm" method="get"><input name="utf8" type="hidden" value="✓"/>
# <input name="const_search_group_ids" type="hidden" value="131">
# <input name="const_search_role_ids" type="hidden" value="1">
# <label>
# <span>Keyword</span>
# <input class="fsConstituentSearchField fsStyleDefaultField" name="const_search_keyword" type="text" value="">
# </input></label>
# <label>
# <span>First Name</span>
# <input class="fsConstituentSearchField fsStyleDefaultField" name="const_search_first_name" type="text" value="">
# </input></label>
# <label>
# <span>Last Name</span>
# <input class="fsConstituentSearchField fsStyleDefaultField" name="const_search_last_name" type="text" value="">
# </input></label>
# <label>
# <span>Department</span>
# <select name="const_search_department">
# <option value="">All Departments</option>
# <option value="265">AASK</option>
# <option value="245">Administration</option>
# <option value="239">Athletics</option>
# <option value="266">Basketball</option>
# <option value="246">Chaplaincy</option>
# <option value="247">College Counseling</option>
# <option value="263">Community Partnerships</option>
# <option value="270">Counseling</option>
# <option value="261">Cross Country</option>
# <option value="232">Dorms</option>
# <option value="260">ELS</option>
# <option value="235">English</option>
# <option value="257">Experiential Education</option>
# <option value="243">Extension</option>
# <option value="268">Golf</option>
# <option value="255">History</option>
# <option value="225">Information Technology</option>
# <option value="269">Lacrosse</option>
# <option value="283">Librarians-Head</option>
# <option value="252">Library</option>
# <option value="244">Mathematics</option>
# <option value="240">Music</option>
# <option value="279">Nurse &amp; Athletic Trainer</option>
# <option value="237">Physical Education</option>
# <option value="253">Private Lessons</option>
# <option value="259">Religion &amp; Philosophy</option>
# <option value="249">Science</option>
# <option value="256">Service Learning</option>
# <option value="273">Skiing</option>
# <option value="267">Soccer</option>
# <option value="236">Student Support</option>
# <option value="250">Tennis</option>
# <option value="254">Track &amp; Field</option>
# <option value="231">Upper School Administration</option>
# <option value="278">US Counseling &amp; Academic Support</option>
# <option value="241">Visual &amp; Performing Arts (VaPA)</option>
# <option value="271">Volleyball</option>
# <option value="227">World Languages</option>
# </select>
# </label>
# <input class="fsConstituentSearchButton fsStyleUpdateButton" type="submit" value="Search Directory">
# </input></input></input></form>
# </div>
# </div>
# <div class="fsElement fsConstituent fsDirectory fsThumbnailOriginal fsThumbnailLarge" id="fsEl_3623">
# <div class="fsElementContent">
# <div class="fsElementPagination" data-searchparams="{}">
# <a class="fsFirstPageLink" data-page="1" disabled="disabled" href="?const_page=1&amp;">1</a>
# <a data-page="2" href="?const_page=2&amp;">2</a>
# <a data-page="3" href="?const_page=3&amp;">3</a>
# <a data-page="5" href="?const_page=5&amp;">…</a>
# <a class="fsLastPageLink" data-page="6" href="?const_page=6&amp;">6</a>
# <a class="fsNextPageLink" data-page="2" data-searchparams="{}" href="?const_page=2&amp;">&gt;</a>
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>
# <div class="fsConstituentColumnLayout_3 fsStyleAutoclear">
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Deri Bash " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Deri_Bash.jpg"/></div>
# <h3 class="fsFullName">
# 				Deri Bash
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Associate Head of Upper School for Academics &amp; Residential Life
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Upper School Administration, Dorms
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2478-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2478-directory", "ude.seo", "dhsab", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9357">
# 						503-416-9357
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Brad Baugher " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Brad_Baugher.jpg"/></div>
# <h3 class="fsFullName">
# 				Brad Baugher
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Director of Educational Technology
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Information Technology
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2480-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2480-directory", "ude.seo", "brehguab", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-768-3136">
# 						503-768-3136
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Carmen Boyle " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Carmen_Boyle.jpg"/></div>
# <h3 class="fsFullName">
# 				Carmen Boyle
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Spanish Teacher
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     World Languages
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2488-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2488-directory", "ude.seo", "celyob", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9238">
# 						503-416-9238
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Peter Buonincontro " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Peter_Buonincontro.jpg"/></div>
# <h3 class="fsFullName">
# 				Peter Buonincontro
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Residential House Head, Theater &amp; Performing Arts Teacher
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Dorms, Visual &amp; Performing Arts (VaPA)
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2493-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2493-directory", "ude.seo", "portnocninoub", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-768-3171">
# 						503-768-3171
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Eduard Cecere " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Eduardo_Cecere.jpg"/></div>
# <h3 class="fsFullName">
# 				Eduard Cecere
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Upper School Technology Coordinator
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Information Technology
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2497-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2497-directory", "ude.seo", "eerecec", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9354">
# 						503-416-9354
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Dennis Chang " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Dennis_Chang.jpg"/></div>
# <h3 class="fsFullName">
# 				Dennis Chang
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Algebra Teacher, Head JV Girls' Soccer Coach
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Athletics, Mathematics
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2499-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2499-directory", "ude.seo", "dgnahc", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9289">
# 						503-416-9289
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Chiman Chen " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Chiman_Chen.jpg"/></div>
# <h3 class="fsFullName">
# 				Chiman Chen
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Mandarin Teacher
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     World Languages
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2500-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2500-directory", "ude.seo", "cnehc", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9267">
# 						503-416-9267
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Corbet Clark " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Corbet_Clark.jpg"/></div>
# <h3 class="fsFullName">
# 				Corbet Clark
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Interim Head of Upper School
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Upper School Administration, Administration
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2501-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2501-directory", "ude.seo", "ckralc", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-768-3121">
# 						503-768-3121
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Jenny Cleveland " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Jenny_Cleveland.jpg"/></div>
# <h3 class="fsFullName">
# 				Jenny Cleveland
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Chaplain, College Counselor
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Chaplaincy, College Counseling
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2504-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2504-directory", "ude.seo", "jdnalevelc", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9242">
# 						503-416-9242
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Bevin Daglen " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Bevin_Daglen.jpg"/></div>
# <h3 class="fsFullName">
# 				Bevin Daglen
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Science Teacher
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Science
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2508-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2508-directory", "ude.seo", "bnelgad", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9320">
# 						503-416-9320
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Tessa Daniel " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Tessa_Daniel.jpg"/></div>
# <h3 class="fsFullName">
# 				Tessa Daniel
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Spanish Teacher, Yearbook
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     World Languages
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2510-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2510-directory", "ude.seo", "tleinad", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9297">
# 						503-416-9297
# 					</a><br>
# </br></br></div>
# </div>
# <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Coleen Davis " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Coleen_Davis.jpg"/></div>
# <h3 class="fsFullName">
# 				Coleen Davis
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Physical Education Teacher, Head Girls' Tennis Coach, SPARC Manager
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Physical Education, Athletics, Tennis
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2511-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2511-directory", "ude.seo", "csivad", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-768-3175">
# 						503-768-3175
# 					</a><br>
# </br></br></div>
# </div>
# </div>
# <div class="fsElementPagination" data-searchparams="{}">
# <a class="fsFirstPageLink" data-page="1" disabled="disabled" href="?const_page=1&amp;">1</a>
# <a data-page="2" href="?const_page=2&amp;">2</a>
# <a data-page="3" href="?const_page=3&amp;">3</a>
# <a data-page="5" href="?const_page=5&amp;">…</a>
# <a class="fsLastPageLink" data-page="6" href="?const_page=6&amp;">6</a>
# <a class="fsNextPageLink" data-page="2" data-searchparams="{}" href="?const_page=2&amp;">&gt;</a>
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# </div>
# <footer class="fsFooter" id="fsFooter">
# <div class=" fsBanner fsStyleAutoclear" id="fsEl_9">
# <div class="fsElement fsContainer address-utility" id="fsEl_946">
# <div class="fsElementContent">
# <div class="fsElement fsContent" id="fsEl_947">
# <div class="fsElementContent">
# <div class="school-details" itemtype="http://schema.org/EducationalOrganization">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
#     <span itemprop="addressRegion">OR</span>,
#     <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-util-footer" id="fsEl_948">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>
# </div>
# </div>
# </div>
# <div class="fsElement fsContent tagline" id="fsEl_949">
# <div class="fsElementContent">
# <p></p><p>Oregon Episcopal School is a college preparatory, independent school in Portland, Oregon, serving 860 students from Pre-Kindergarten through Grade 12, including 60 boarding students from around the world in Grades 9-12.</p><p></p>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-social" id="fsEl_950">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://www.facebook.com/oregon.episcopal" target="_blank">Facebook</a></li><li><a href="http://twitter.com/oregonepiscopal" target="_blank">Twitter</a></li><li><a href="http://www.youtube.com/user/OESTV" target="_blank">Youtube</a></li><li><a href="https://instagram.com/oregonepiscopal" target="_blank">Instagram</a></li></ul></nav>
# </div>
# </div>
# </div>
# </footer>
# <div id="fsPoweredByFinalsite">
# <div>
# <a href="http://www.finalsite.com" target="_blank">Powered by Finalsite</a>
# </div>
# </div>
# </div>, <div id="fsMenu">
# <div class=" fsMenu fsStyleAutoclear" id="fsEl_493">
# <div class="fsElement fsContent close-button-container" id="fsEl_920">
# <div class="fsElementContent">
# <button class="drawer-trigger" href="#"></button>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_494">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li class="fsNavParentPage"><a href="/aboutoes/leadership">Leadership</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/leadership/board-of-trustees">Board of Trustees Information</a></li></ul></div></li><li class="fsNavParentPage"><a href="/aboutoes/strategic-plan">Strategic Plan</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/strategic-plan/program">Program</a></li><li><a href="/aboutoes/strategic-plan/people">People</a></li><li><a href="/aboutoes/strategic-plan/place">Place</a></li><li><a href="/aboutoes/strategic-plan/plan">Plan</a></li></ul></div></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li class="fsNavParentPage"><a href="/aboutoes/community-partnerships">Community Partnerships</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/community-partnerships/aardvarks-advocate-for-skills-knowledge-aask">Aardvarks Advocate for Skills &amp; Knowledge (AASK)</a></li><li><a href="/aboutoes/community-partnerships/community-conversations">Community Conversations</a></li><li><a href="/aboutoes/community-partnerships/spring-event">Spring Event</a></li></ul></div></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/admissions/inquire">Inquire</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/inquire/admissionsfaqs">Admissions FAQs</a></li><li><a href="/admissions/inquire/parent-tours">Parent Tours</a></li><li><a href="/admissions/inquire/student-visits">Student Visits</a></li><li><a href="/admissions/inquire/open-house">Open House</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/application-process">Application Process</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/application-process/ssat">SSAT</a></li><li><a href="/admissions/application-process/toefl">TOEFL</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/tuition-financial-aid/financial-aid-faqs">Financial Aid FAQs</a></li><li><a href="/admissions/tuition-financial-aid/faapplication">Financial Aid Application</a></li></ul></div></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/academics/academic-curriculum">Academic Curriculum</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/academics/academic-curriculum/our-approach">Our Approach</a></li><li class="fsNavParentPage"><a href="/academics/academic-curriculum/arts">Arts</a><div class="fsNavPageInfo"><ul class="fsNavLevel4"><li><a hr ...
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_1070">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li><a href="/contact-us">Contact Us</a></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_1071">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
# </div>
# </div>
# </div>, <div class=" fsMenu fsStyleAutoclear" id="fsEl_493">
# <div class="fsElement fsContent close-button-container" id="fsEl_920">
# <div class="fsElementContent">
# <button class="drawer-trigger" href="#"></button>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-main" id="fsEl_494">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li class="fsNavParentPage"><a href="/aboutoes/leadership">Leadership</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/leadership/board-of-trustees">Board of Trustees Information</a></li></ul></div></li><li class="fsNavParentPage"><a href="/aboutoes/strategic-plan">Strategic Plan</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/strategic-plan/program">Program</a></li><li><a href="/aboutoes/strategic-plan/people">People</a></li><li><a href="/aboutoes/strategic-plan/place">Place</a></li><li><a href="/aboutoes/strategic-plan/plan">Plan</a></li></ul></div></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li class="fsNavParentPage"><a href="/aboutoes/community-partnerships">Community Partnerships</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/community-partnerships/aardvarks-advocate-for-skills-knowledge-aask">Aardvarks Advocate for Skills &amp; Knowledge (AASK)</a></li><li><a href="/aboutoes/community-partnerships/community-conversations">Community Conversations</a></li><li><a href="/aboutoes/community-partnerships/spring-event">Spring Event</a></li></ul></div></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/admissions/inquire">Inquire</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/inquire/admissionsfaqs">Admissions FAQs</a></li><li><a href="/admissions/inquire/parent-tours">Parent Tours</a></li><li><a href="/admissions/inquire/student-visits">Student Visits</a></li><li><a href="/admissions/inquire/open-house">Open House</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/application-process">Application Process</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/application-process/ssat">SSAT</a></li><li><a href="/admissions/application-process/toefl">TOEFL</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/tuition-financial-aid/financial-aid-faqs">Financial Aid FAQs</a></li><li><a href="/admissions/tuition-financial-aid/faapplication">Financial Aid Application</a></li></ul></div></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/academics/academic-curriculum">Academic Curriculum</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/academics/academic-curriculum/our-approach">Our Approach</a></li><li class="fsNavParentPage"><a href="/academics/academic-curriculum/arts">Arts</a><div class="fsNavPageInfo"><ul class="fsNavLevel4"><li><a hr ...
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-util-header" id="fsEl_1070">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://summer.oes.edu" target="_blank">Summer</a></li><li><a href="/contact-us">Contact Us</a></li><li><a href="/campus-resources">Campus Resources</a></li><li class="calendar"><a href="/calendar">Calendar</a></li><li class="shopping"><a href="http://store.oes.edu/" target="_blank">Shopping Cart</a></li><li class="search"><a href="/search">Search</a></li></ul></nav>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-portals" id="fsEl_1071">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/parents">Parents</a></li><li><a href="/employees">Employees</a></li><li><a href="/students">Students</a></li><li><a href="/alumni">Alumni</a></li></ul></nav>
# </div>
# </div>
# </div>, <div class="fsElement fsContent close-button-container" id="fsEl_920">
# <div class="fsElementContent">
# <button class="drawer-trigger" href="#"></button>
# </div>
# </div>, <div class="fsElementContent">
# <button class="drawer-trigger" href="#"></button>
# </div>, <div class="fsElement fsNavigation fsList nav-main" id="fsEl_494">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li class="fsNavParentPage"><a href="/aboutoes">ABOUT OES</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/aboutoes/ataglance">OES At a Glance</a></li><li><a href="/aboutoes/welcome-from-head-of-school">Welcome From Head of School</a></li><li><a href="/aboutoes/mission-vision-identity">Mission, Vision, and Identity</a></li><li><a href="/aboutoes/history">Brief History</a></li><li class="fsNavParentPage"><a href="/aboutoes/leadership">Leadership</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/leadership/board-of-trustees">Board of Trustees Information</a></li></ul></div></li><li class="fsNavParentPage"><a href="/aboutoes/strategic-plan">Strategic Plan</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/strategic-plan/program">Program</a></li><li><a href="/aboutoes/strategic-plan/people">People</a></li><li><a href="/aboutoes/strategic-plan/place">Place</a></li><li><a href="/aboutoes/strategic-plan/plan">Plan</a></li></ul></div></li><li><a href="/aboutoes/episcopal-tradition">Episcopal Tradition</a></li><li class="fsNavParentPage"><a href="/aboutoes/community-partnerships">Community Partnerships</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/aboutoes/community-partnerships/aardvarks-advocate-for-skills-knowledge-aask">Aardvarks Advocate for Skills &amp; Knowledge (AASK)</a></li><li><a href="/aboutoes/community-partnerships/community-conversations">Community Conversations</a></li><li><a href="/aboutoes/community-partnerships/spring-event">Spring Event</a></li></ul></div></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions">ADMISSIONS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/admissions/inquire">Inquire</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/inquire/admissionsfaqs">Admissions FAQs</a></li><li><a href="/admissions/inquire/parent-tours">Parent Tours</a></li><li><a href="/admissions/inquire/student-visits">Student Visits</a></li><li><a href="/admissions/inquire/open-house">Open House</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/application-process">Application Process</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/application-process/ssat">SSAT</a></li><li><a href="/admissions/application-process/toefl">TOEFL</a></li></ul></div></li><li class="fsNavParentPage"><a href="/admissions/tuition-financial-aid">Tuition &amp; Financial Aid</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/admissions/tuition-financial-aid/financial-aid-faqs">Financial Aid FAQs</a></li><li><a href="/admissions/tuition-financial-aid/faapplication">Financial Aid Application</a></li></ul></div></li><li><a href="/admissions/oes-experience">Student  Experience</a></li><li><a href="/admissions/international-students">International Students</a></li><li><a href="/admissions/admissions-travel">Admissions Travel</a></li><li><a href="/admissions/admissions-team">Admissions Team</a></li></ul></div></li><li class="fsNavParentPage"><a href="/boarding">BOARDING</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li><a href="/boarding/a-global-community">A Global Community</a></li><li><a href="/boarding/building-independence">Building Independence</a></li><li><a href="/boarding/portland">Living in Portland</a></li><li><a href="/boarding/faqs">Boarding FAQs</a></li></ul></div></li><li class="fsNavParentPage fsNavCurrentPageAncestor"><a href="/academics">ACADEMICS</a><div class="fsNavPageInfo"><ul class="fsNavLevel2"><li class="fsNavParentPage"><a href="/academics/academic-curriculum">Academic Curriculum</a><div class="fsNavPageInfo"><ul class="fsNavLevel3"><li><a href="/academics/academic-curriculum/our-approach">Our Approach</a></li><li class="fsNavParentPage"><a href="/academics/academic-curriculum/arts">Arts</a><div class="fsNavPageInfo"><ul class="fsNavLevel4"><li><a hr ...
# </div>
# </div>, <div class="fsElementContent">
# ...
# <div id="fsEmail-3623-2504-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2504-directory", "ude.seo", "jdnalevelc", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9242">
# 						503-416-9242
# 					</a><br>
# </br></br></div>
# </div>, <div class="fsPhoto"><img alt="Jenny Cleveland " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Jenny_Cleveland.jpg"/></div>, <div class="fsTitles">
# <strong>Titles:</strong>
#     Chaplain, College Counselor
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Chaplaincy, College Counseling
# </div>, <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2504-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2504-directory", "ude.seo", "jdnalevelc", false); }, 20);</script>
# </div>
# </div>, <div id="fsEmail-3623-2504-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2504-directory", "ude.seo", "jdnalevelc", false); }, 20);</script>
# </div>, <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9242">
# 						503-416-9242
# 					</a><br>
# </br></br></div>, <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Bevin Daglen " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Bevin_Daglen.jpg"/></div>
# <h3 class="fsFullName">
# 				Bevin Daglen
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Science Teacher
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Science
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2508-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2508-directory", "ude.seo", "bnelgad", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9320">
# 						503-416-9320
# 					</a><br>
# </br></br></div>
# </div>, <div class="fsPhoto"><img alt="Bevin Daglen " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Bevin_Daglen.jpg"/></div>, <div class="fsTitles">
# <strong>Titles:</strong>
#     Science Teacher
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Science
# </div>, <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2508-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2508-directory", "ude.seo", "bnelgad", false); }, 20);</script>
# </div>
# </div>, <div id="fsEmail-3623-2508-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2508-directory", "ude.seo", "bnelgad", false); }, 20);</script>
# </div>, <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9320">
# 						503-416-9320
# 					</a><br>
# </br></br></div>, <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Tessa Daniel " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Tessa_Daniel.jpg"/></div>
# <h3 class="fsFullName">
# 				Tessa Daniel
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Spanish Teacher, Yearbook
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     World Languages
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2510-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2510-directory", "ude.seo", "tleinad", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9297">
# 						503-416-9297
# 					</a><br>
# </br></br></div>
# </div>, <div class="fsPhoto"><img alt="Tessa Daniel " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Tessa_Daniel.jpg"/></div>, <div class="fsTitles">
# <strong>Titles:</strong>
#     Spanish Teacher, Yearbook
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     World Languages
# </div>, <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2510-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2510-directory", "ude.seo", "tleinad", false); }, 20);</script>
# </div>
# </div>, <div id="fsEmail-3623-2510-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2510-directory", "ude.seo", "tleinad", false); }, 20);</script>
# </div>, <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-416-9297">
# 						503-416-9297
# 					</a><br>
# </br></br></div>, <div class="fsConstituentItem fsHasPhoto">
# <div class="fsPhoto"><img alt="Coleen Davis " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Coleen_Davis.jpg"/></div>
# <h3 class="fsFullName">
# 				Coleen Davis
# 		</h3>
# <div class="fsTitles">
# <strong>Titles:</strong>
#     Physical Education Teacher, Head Girls' Tennis Coach, SPARC Manager
# </div>
# <div class="fsDepartments">
# <strong>Departments:</strong>
#     Physical Education, Athletics, Tennis
# </div>
# <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2511-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2511-directory", "ude.seo", "csivad", false); }, 20);</script>
# </div>
# </div>
# <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-768-3175">
# 						503-768-3175
# 					</a><br>
# </br></br></div>
# </div>, <div class="fsPhoto"><img alt="Coleen Davis " class="fsThumbnail" src="/uploaded/New_Site/Employee_Directory/Coleen_Davis.jpg"/></div>, <div class="fsTitles">
# <strong>Titles:</strong>
#     Physical Education Teacher, Head Girls' Tennis Coach, SPARC Manager
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Physical Education, Athletics, Tennis
# </div>, <div class="fsEmail">
# <strong>Email: </strong>
# <div id="fsEmail-3623-2511-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2511-directory", "ude.seo", "csivad", false); }, 20);</script>
# </div>
# </div>, <div id="fsEmail-3623-2511-directory">
# <script type="text/javascript">setTimeout(function(){ FS.util.insertEmail("fsEmail-3623-2511-directory", "ude.seo", "csivad", false); }, 20);</script>
# </div>, <div class="fsPhones">
# <strong>Phone Numbers:</strong><br>
# 					School:
# 					<a href="tel:503-768-3175">
# 						503-768-3175
# 					</a><br>
# </br></br></div>, <div class="fsElementPagination" data-searchparams="{}">
# <a class="fsFirstPageLink" data-page="1" disabled="disabled" href="?const_page=1&amp;">1</a>
# <a data-page="2" href="?const_page=2&amp;">2</a>
# <a data-page="3" href="?const_page=3&amp;">3</a>
# <a data-page="5" href="?const_page=5&amp;">…</a>
# <a class="fsLastPageLink" data-page="6" href="?const_page=6&amp;">6</a>
# <a class="fsNextPageLink" data-page="2" data-searchparams="{}" href="?const_page=2&amp;">&gt;</a>
# <span class="fsPaginationLabel">showing 1 - 12 of 71 constituents</span>
# </div>, <div class=" fsBanner fsStyleAutoclear" id="fsEl_9">
# <div class="fsElement fsContainer address-utility" id="fsEl_946">
# <div class="fsElementContent">
# <div class="fsElement fsContent" id="fsEl_947">
# <div class="fsElementContent">
# <div class="school-details" itemtype="http://schema.org/EducationalOrganization">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
#     <span itemprop="addressRegion">OR</span>,
#     <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-util-footer" id="fsEl_948">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>
# </div>
# </div>
# </div>
# <div class="fsElement fsContent tagline" id="fsEl_949">
# <div class="fsElementContent">
# <p></p><p>Oregon Episcopal School is a college preparatory, independent school in Portland, Oregon, serving 860 students from Pre-Kindergarten through Grade 12, including 60 boarding students from around the world in Grades 9-12.</p><p></p>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-social" id="fsEl_950">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://www.facebook.com/oregon.episcopal" target="_blank">Facebook</a></li><li><a href="http://twitter.com/oregonepiscopal" target="_blank">Twitter</a></li><li><a href="http://www.youtube.com/user/OESTV" target="_blank">Youtube</a></li><li><a href="https://instagram.com/oregonepiscopal" target="_blank">Instagram</a></li></ul></nav>
# </div>
# </div>
# </div>, <div class="fsElement fsContainer address-utility" id="fsEl_946">
# <div class="fsElementContent">
# <div class="fsElement fsContent" id="fsEl_947">
# <div class="fsElementContent">
# <div class="school-details" itemtype="http://schema.org/EducationalOrganization">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
#     <span itemprop="addressRegion">OR</span>,
#     <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-util-footer" id="fsEl_948">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>
# </div>
# </div>
# </div>, <div class="fsElementContent">
# <div class="fsElement fsContent" id="fsEl_947">
# <div class="fsElementContent">
# <div class="school-details" itemtype="http://schema.org/EducationalOrganization">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
#     <span itemprop="addressRegion">OR</span>,
#     <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
# </div>
# </div>
# <div class="fsElement fsNavigation fsList nav-util-footer" id="fsEl_948">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>
# </div>
# </div>, <div class="fsElement fsContent" id="fsEl_947">
# <div class="fsElementContent">
# <div class="school-details" itemtype="http://schema.org/EducationalOrganization">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
#     <span itemprop="addressRegion">OR</span>,
#     <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
# </div>
# </div>, <div class="fsElementContent">
# <div class="school-details" itemtype="http://schema.org/EducationalOrganization">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
#     <span itemprop="addressRegion">OR</span>,
#     <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>
# </div>, <div class="school-details" itemtype="http://schema.org/EducationalOrganization">
# <div itemprop="name">Oregon Episcopal School</div>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
#     <span itemprop="addressRegion">OR</span>,
#     <span itemprop="postalCode">97223</span>
# </div>
# <span itemprop="telephone">503-246-7771</span>
# <span itemprop="fax">Fax: 503-293-1105</span>
# </div>, <div itemprop="name">Oregon Episcopal School</div>, <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <span itemprop="streetAddress">6300 SW Nicol Road</span><span class="hidemobile"> |</span>
# <span itemprop="addressLocality">Portland</span>,
#     <span itemprop="addressRegion">OR</span>,
#     <span itemprop="postalCode">97223</span>
# </div>, <div class="fsElement fsNavigation fsList nav-util-footer" id="fsEl_948">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>
# </div>, <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="/contact-us">Contact Us</a></li><li><a href="/careers">Careers</a></li><li><a href="/webmaster">Webmaster</a></li><li><a href="/privacypolicy">Privacy Policy </a></li><li><a href="/site-map">Site Map</a></li></ul></nav>
# </div>, <div class="fsElement fsContent tagline" id="fsEl_949">
# <div class="fsElementContent">
# <p></p><p>Oregon Episcopal School is a college preparatory, independent school in Portland, Oregon, serving 860 students from Pre-Kindergarten through Grade 12, including 60 boarding students from around the world in Grades 9-12.</p><p></p>
# </div>
# </div>, <div class="fsElementContent">
# <p></p><p>Oregon Episcopal School is a college preparatory, independent school in Portland, Oregon, serving 860 students from Pre-Kindergarten through Grade 12, including 60 boarding students from around the world in Grades 9-12.</p><p></p>
# </div>, <div class="fsElement fsNavigation fsList nav-social" id="fsEl_950">
# <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://www.facebook.com/oregon.episcopal" target="_blank">Facebook</a></li><li><a href="http://twitter.com/oregonepiscopal" target="_blank">Twitter</a></li><li><a href="http://www.youtube.com/user/OESTV" target="_blank">Youtube</a></li><li><a href="https://instagram.com/oregonepiscopal" target="_blank">Instagram</a></li></ul></nav>
# </div>
# </div>, <div class="fsElementContent">
# <nav><ul class="fsNavLevel1"><li><a href="http://www.facebook.com/oregon.episcopal" target="_blank">Facebook</a></li><li><a href="http://twitter.com/oregonepiscopal" target="_blank">Twitter</a></li><li><a href="http://www.youtube.com/user/OESTV" target="_blank">Youtube</a></li><li><a href="https://instagram.com/oregonepiscopal" target="_blank">Instagram</a></li></ul></nav>
# </div>, <div id="fsPoweredByFinalsite">
# <div>
# <a href="http://www.finalsite.com" target="_blank">Powered by Finalsite</a>
# </div>
# </div>, <div>
# <a href="http://www.finalsite.com" target="_blank">Powered by Finalsite</a>
# </div>]

# %% [markdown]
# That's still too much info. To narrow down our search, we can use BeautifulSoup and the findAll command to find the classes labeled "fsDepartments":

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff').read()
soup = BeautifulSoup(fhand, "html.parser")

headers = soup('div')

divs = soup.findAll("div", { "class" : "fsDepartments" })
for div in divs:
    print(div.get_text())
print(mydivs)
# Out:
# Departments:
#     Upper School Administration, Dorms
#
#
# Departments:
#     Information Technology
#
#
# Departments:
#     World Languages
#
#
# Departments:
#     Dorms, Visual & Performing Arts (VaPA)
#
#
# Departments:
#     Information Technology
#
#
# Departments:
#     Athletics, Mathematics
#
#
# Departments:
#     World Languages
#
#
# Departments:
#     Upper School Administration, Administration
#
#
# Departments:
#     Chaplaincy, College Counseling
#
#
# Departments:
#     Science
#
#
# Departments:
#     World Languages
#
#
# Departments:
#     Physical Education, Athletics, Tennis
#
# [<div class="fsDepartments">
# <strong>Departments:</strong>
#     Upper School Administration, Dorms
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Information Technology
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     World Languages
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Dorms, Visual &amp; Performing Arts (VaPA)
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Information Technology
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Athletics, Mathematics
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     World Languages
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Upper School Administration, Administration
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Chaplaincy, College Counseling
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Science
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     World Languages
# </div>, <div class="fsDepartments">
# <strong>Departments:</strong>
#     Physical Education, Athletics, Tennis
# </div>]

# %%
import urllib.request, urllib.parse, urllib.error
from urllib.request import urlopen
from bs4 import BeautifulSoup

fhand = urllib.request.urlopen('https://www.oes.edu/academics/upper-school/faculty-staff').read()

soup = BeautifulSoup(fhand, "html.parser")

headers = soup('p')
for header in headers:
    print(header)
# Out:
# <p></p>
# <p>Oregon Episcopal School is a college preparatory, independent school in Portland, Oregon, serving 860 students from Pre-Kindergarten through Grade 12, including 60 boarding students from around the world in Grades 9-12.</p>
# <p></p>

# %% [markdown]
# Let's use Beautiful Soup and Requests to find the temperature for Portland using www.weatherunderground.com. We can

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.wunderground.com/weather-forecast/97217'
response = requests.get(url)
print(response.text)
soup = BeautifulSoup(response.text, "html.parser")
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="no-js ie9"> <![endif]-->
# <!--[if gt IE 9]><!--> <html class="no-js "> <!--<![endif]-->
# 	<head>
# 		<title>Portland, OR (97217) Forecast | Weather Underground</title>
# 		<link href="//icons.wxug.com/" rel="dns-prefetch" />
# 		<link href="//api-ak.wunderground.com/" rel="dns-prefetch" />
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <meta name="description" content="">
# <meta name="HandheldFriendly" content="True">
# <meta name="MobileOptimized" content="320">
# <meta name="viewport" content="width=device-width, initial-scale=1, minimal-ui">
# <meta http-equiv="cleartype" content="on">
# 	<meta name="description" content="Get latest forecast for Portland, OR (97217) weather along with updates about temperature, humidity, weather radar and more on Weather Underground." />
# 	<meta name="keywords" content="97217 weather, Portland OR weather, weather in Portland, 97217 weather forecast" />
# 	<meta property="og:site_name" content="Weather Underground" />
# 	<meta property="og:type" content="article" />
# 		<meta property="og:url" content="https://www.wunderground.com/us/or/portland" />
# 	<meta property="og:image" content="https://icons.wxug.com/i/c/k2/partlycloudy.png" />
# 	<meta property="og:title" content="Portland, OR | 65.4&deg; | Partly Cloudy" />
# 		<meta name="apple-itunes-app" content="app-id=486154808, affiliate-data=at=1010lrYB&ct=website_wu" />
# <meta name="fb-app-id" content="325331260891611" />
# <meta name="fb-channel-url" content="//www.wunderground.com/php/lib/fb_sdk/channel.php" />
# <meta name="wui-member-logged-in" content="false" />
# <meta name="com.silverpop.brandeddomains" content="www.pages02.net,www.wunderground.com" />
# 		<meta http-equiv="Refresh" content="300;URL=/weather-forecast/97217?MR=1" />
# 		<link rel="canonical" href="https://www.wunderground.com/us/or/portland" />
# 		<link rel="alternate" type="application/rss+xml" title="Portland, Oregon RSS" href="https://www.wunderground.com/auto/rss_full/OR/Portland.xml" />
# 	<link rel="apple-touch-icon" href="//icons.wxug.com/favicon.png"/>
# 	<link rel="shortcut icon" type="image/png" href="//icons.wxug.com/favicon.png"/>
# 	<link rel="stylesheet" href="//icons.wxug.com/css/wu4/core.css?v=2017041301">
# 	<link rel="stylesheet" href="//icons.wxug.com/css/wu4/omnibus.css?v=2017050501">
# 	<script src="//icons.wxug.com/scripts/modernizr/2.8.2/modernizr.min.js"></script>
# 		<script type="text/javascript">
# 	if (typeof Object.assign != 'function') {
# 	 Object.assign = function(target) {
# 	 'use strict';
# 	 if (target == null) {
# 	 throw new TypeError('Cannot convert undefined or null to object');
# 	 }
# 	 target = Object(target);
# 	 for (var index = 1; index < arguments.length; index++) {
# 	      var source = arguments[index];
# 	      if (source != null) {
# 	        for (var key in source) {
# 	          if (Object.prototype.hasOwnProperty.call(source, key)) {
# 	            target[key] = source[key];
# 	          }
# 	        }
# 	      }
# 	    }
# 	    return target;
# 	  };
# 	}
#
#   if (window.innerWidth >= 1025) {
# 		var ad_unit = 'web_wunderground_us/local_forecasts/today';
# 		var ad_plat = 'wund';
# 		var wfx_id = 'B1CC73';
# 		var pos1 = 'wx_ws';
# 		var pos1Sizes = [[728,90],[728,91],[970,90],[970,250]];
# 		var pos2Id = 'WX_Top300Variable';
# 		var pos2 = 'wx_300var';
# 		var pos2Sizes = [[300,600],[300,250],[300,251]];
# 		var pos3Id = 'div-gpt-ad-615639597871654305-3';
# 		var pos3 = 'wx_hsd';
# 		var pos3Sizes = [[728,91]];
# 		var pos4Id = 'div-gpt-ad-615639597871654305-4';
# 		var pos4 = 'wx_mid300';
# 		var pos4Sizes = [[300,251]];
# 		var pos5Id = 'div-gpt-ad-615639597871654305-5';
# 		var pos5 = 'wx_pds';
# 		var pos5Sizes = [[300,251]];
# 		var pos6Id = 'div-gpt-ad-615639597871654305-6';
# 		var pos6 = 'wx_bot300';
# 		var pos6Sizes = [[300,251]];
# 		var pos7Id = 'div-gpt-ad-615639597871654305-7';
# 		var pos7 = 'wx_midldr';
# 		var pos7Sizes = [[728,91]];
# 		var pos8Id = 'div-gpt-ad-615639597871654305-8';
# 		var pos8 = 'wx_bot300_1';
# 		var pos8Sizes = [[300,251]];
# 		var pos9 = 'wx_botldr';
# 		var pos9Sizes = [[728,91]];
# 	}
#   else if (window.innerWidth >= 768) {
# 		var ad_unit = 'tablet_wunderground_us/local_forecasts/today';
# 		var ad_plat = 'wund_tab';
# 		var wfx_id = 'B1CC73';
# 		var pos1 = 'wx_ws';
# 		var pos1Sizes = [[728,90],[728,91],[728,92]];
# 		var pos2Id = 'WX_Top300Variable';
# 		var pos2 = 'wx_300var';
# 		var pos2Sizes = [[300,250],[300,251]];
# 		var pos3Id = 'div-gpt-ad-615639597871654305-3';
# 		var pos3 = 'wx_hsd';
# 		var pos3Sizes = [[728,91]];
# 		var pos4Id = 'div-gpt-ad-615639597871654305-4';
# 		var pos4 = 'wx_mid300';
# 		var pos4Sizes = [[300,251]];
# 		var pos5Id = 'div-gpt-ad-615639597871654305-5';
# 		var pos5 = 'wx_pds';
# 		var pos5Sizes = [[300,251]];
# 		var pos6Id = 'div-gpt-ad-615639597871654305-6';
# 		var pos6 = 'wx_bot300';
# 		var pos6Sizes = [[300,251]];
# 		var pos7Id = 'div-gpt-ad-615639597871654305-7';
# 		var pos7 = 'wx_midldr';
# 		var pos7Sizes = [[728,91]];
# 		var pos8Id = 'div-gpt-ad-615639597871654305-8';
# 		var pos8 = 'wx_bot300_1';
# 		var pos8Sizes = [[300,251]];
# 		var pos9 = 'wx_botldr';
# 		var pos9Sizes = [[728,91],[728,92]];
# 	}
# 	else {
# 		var adLimitMobile = 5;
# 		var ad_unit = 'mobile_smart_wunderground_us/local_forecasts/today';
# 		var ad_plat = 'wund_mw';
# 		var wfx_id = '5B3739';
# 		var pos1 = 'mw_p1';
# 		var pos1Sizes = [[320,51]];
# 		var pos2Id = 'WX_Top300Variable';
# 		var pos2 = 'mw_p2';
# 		var pos2Sizes = [[300,251]];
# 		var pos3Id = 'div-gpt-ad-615639597871654305-3';
# 		var pos3 = 'mw_p3';
# 		var pos3Sizes = [[300,251]];
# 		var pos4Id = 'div-gpt-ad-615639597871654305-4';
# 		var pos4 = 'mw_p4';
# 		var pos4Sizes = [[300,251]];
# 		var pos5Id = 'div-gpt-ad-615639597871654305-5';
# 		var pos5 = 'mw_p5';
# 		var pos5Sizes = [[300,251]];
# 	}
#   window.Adomik = window.Adomik || {};
#   Adomik.randomAdGroup = function() {
#   var rand = Math.random();
#   switch (false) {
#   case !(rand < 0.09): return "ad_ex" + (Math.floor(100 * rand));
#       case !(rand < 0.10): return "ad_bc";
#       default: return "ad_opt";
#     }
#   };
#
# 	var isEdge = navigator.userAgent.indexOf('Edge') >=0;
# 	var isOpera = !!window.opera || navigator.userAgent.indexOf(' OPR/') >= 0;
# 	var isFirefox = typeof InstallTrigger !== 'undefined';
# 	var isSafari = Object.prototype.toString.call(window.HTMLElement).indexOf('Constructor') > 0;
# 	var isChrome = !!window.chrome && !isOpera && !isEdge;
# 	var isIE = /*@cc_on!@*/false || !!document.documentMode;
# 	var browser_type = null;
# 	if (isFirefox) {
# 		browser_type = 'wuff';
# 	} else if (isSafari) {
# 		browser_type = 'wusafari';
# 	} else if (isChrome) {
# 		browser_type = 'wuchrome'
# 	} else if (isIE) {
# 		browser_type = 'wuie';
# 	} else if (isEdge) {
# 		browser_type = 'wuedge';
# 	}
# </script>
# <script src="//icons.wxug.com/scripts/ads-sdk/index.min.js?v=1.1" async></script>
# <script type="text/javascript">
#   // common metadata section
#   var refurl = {};
#   var adZone = '';
# 	var locale = 'en-US';
#   var thirdParties = [{"id":"wfxtg","acctid":wfx_id,"timeout":500,"params":{"activeLocation":"97217"},"async":true},{"id":"criteo","netId":1458,"timeout":500,"async":true},{"id":"amznslots","amznId":1004,"async":true,"timeout":500,"iso":true},{"id":"lotame","clientId":2216,"async":true,"timeout":500}] || [];
#   var custParams = {
# 	 "locale":"en_US",
# 	 "lang":"EN",
# 	 "dma":"820",
# 	 "lat":"45.56999969",
# 	 "lon":"-122.69000244",
# 	 "loc":"97217",
# 	 "zip":"97217",
# 	 "ct":"Portland",
# 	 "st":"OR",
# 	 "cnty":"Multnomah",
# 	 "cc":"US",
# 	 "countryName":"United States"
# 	};
#   // common part for queue definition
#   window.TWC = window.TWC || {};
#   window.TWC.adUtils = window.TWC.adUtils || {};
#   window.twcMoney = window.twcMoney || {};
#   window.twcMoney.cmd = window.twcMoney.cmd || [];
# </script>
# <script type="text/javascript">
# 	var preparePositions = [];
# 	 preparePositions.push({
#   "id": "WX_WindowShade",
#   "pos": pos1,
#   "sizes": pos1Sizes
# 		});
#  	var adNum = 2;
# 		if ((ad_plat === 'wund') || (ad_plat === 'wund_tab') || (adNum <= adLimitMobile && ad_plat === 'wund_mw')) {
# 			preparePositions.push({
# 				"id": pos2Id,
# 				"pos": pos2,
# 				"sizes": pos2Sizes
# 			});
# 		}
#
# 		adNum = 3;
#
# 		if ((ad_plat === 'wund') || (ad_plat === 'wund_tab') || (adNum <= adLimitMobile && ad_plat === 'wund_mw')) {
# 			preparePositions.push({
# 				"id": pos3Id,
# 				"pos": pos3,
# 				"sizes": pos3Sizes
# 			});
# 		}
#
# 		adNum = 4;
#
# 		if ((ad_plat === 'wund') || (ad_plat === 'wund_tab') || (adNum <= adLimitMobile && ad_plat === 'wund_mw')) {
# 			preparePositions.push({
# 				"id": pos4Id,
# 				"pos": pos4,
# 				"sizes": pos4Sizes
# 			});
# 		}
#
# 		adNum = 5;
#
# 		if ((ad_plat === 'wund') || (ad_plat === 'wund_tab') || (adNum <= adLimitMobile && ad_plat === 'wund_mw')) {
# 			preparePositions.push({
# 				"id": pos5Id,
# 				"pos": pos5,
# 				"sizes": pos5Sizes
# 			});
# 		}
#
# 		adNum = 6;
#
# 		if ((ad_plat === 'wund') || (ad_plat === 'wund_tab') || (adNum <= adLimitMobile && ad_plat === 'wund_mw')) {
# 			preparePositions.push({
# 				"id": pos6Id,
# 				"pos": pos6,
# 				"sizes": pos6Sizes
# 			});
# 		}
#
# 		adNum = 7;
#
# 		if ((ad_plat === 'wund') || (ad_plat === 'wund_tab') || (adNum <= adLimitMobile && ad_plat === 'wund_mw')) {
# 			preparePositions.push({
# 				"id": pos7Id,
# 				"pos": pos7,
# 				"sizes": pos7Sizes
# 			});
# 		}
#
# 		adNum = 8;
#
# 		if ((ad_plat === 'wund') || (ad_plat === 'wund_tab') || (adNum <= adLimitMobile && ad_plat === 'wund_mw')) {
# 			preparePositions.push({
# 				"id": pos8Id,
# 				"pos": pos8,
# 				"sizes": pos8Sizes
# 			});
# 		}
#
# 		adNum = 9;
#
#
#
# 		if ((ad_plat === 'wund') || (ad_plat === 'wund_tab') || (adNum <= adLimitMobile && ad_plat === 'wund_mw')) {
#   	    	preparePositions.push({
# 			    "id": "div-gpt-ad-615639597871654305-bot",
# 			    "pos": pos9,
# 			    "sizes": pos9Sizes
# 			});
# 		}
#
#
#   var customAdConfig = {
#     preparePositions: preparePositions,
#     getAdUnit: {
#     	adUnit: ad_unit,
#       networkCode: '/7646'
#     },
#     getCustParams: {
#       plat: ad_plat,
#
#
# 				lo: 'wx_t3bbf',
# 				tf: 'today',
#
#
#
# 				excl: 'wund',
#
#
# 			ad_g : Adomik.randomAdGroup(),
#
# 			preempt : "y"
#     },
#
#     getClientBrowser: browser_type
#   };
#
#   var start = window.performance.now();
#
#   window.twcMoney.cmd.push(function() {
#     window.twcMoney
#       .moneyTree({ useLightSpeed: true, locale: locale, lsScriptUrl: '//js-sec.indexww.com/ht/p/182970-203800257961387.js' })
#       .start({
#         adZone: adZone,
#         locale: locale,
#         thirdParties: thirdParties,
#         custParams: custParams,
#         pageAdPositions: [],
#
#         staticAdPositions: [true],
#         processStatic: true,
#         adConfig: customAdConfig
#       });
#   });
# </script>
# 	</head>
# 	<body class="standard CityPage-ZipForecast city-page  ">
# 		<div id="content-wrap" class="relative right-side-nav">
# 		<nav id="feature-menu-mobile" class="sidebar">
#   <div class="sidebar-wrapper">
#   <ul class="side-main-nav nav-bar">
#   <li>
#   <a href="/login.asp">Log in</a>
#   </li>
#   <li>
#   <a href="/member/registration">Join</a>
#   </li>
#   </a>
#   <ul class="sideSubNav">
#   <li class="sideGoBack"><a href="javascript:void(0);"></a></li>
#   <li class="sidebar-heading no-link">
# 	 Hello&#33;
# </li>
# <li><a href="/member/membersettings.html">Member Settings</a></li>
# <li><a href="/email/mainmenu.php">My Email Alerts</a></li>
# <li><a href="/webcams/signup.html" class="brBot3">My Webcams</a></li>
# <li><a href="/email/logout.php">Sign Out</a></li>
#   </ul>
#   </li>
#   <li class="gotMore">
#   <a href="#">
#   <i class="fi-widget sidebar-icon"></i> Settings
#   </a>
#   <ul class="sideSubNav">
#   <li class="sideGoBack"><a href="javascript:void(0);">Settings</a></li>
#   <ul class="button-group toggle radius">
#   <li><a onclick="wui.SetUnitToEnglish()" title="Switch to English" class="button selected">&deg;F</a></li>
#   <li><a onclick="wui.SetUnitToMetric()" title="Switch to Metric" class="button ">&deg;C</a></li>
# </ul>
# <ul class="button-group radius toggle compact forecast-type">
#   <li><a href="/cgi-bin/findweather/getForecast?setpref=EXPFCT&value=1&referer=%2fweather%2dforecast%2f97217" title="Use BestForecast" class="button selected" onclick="_gaq.push(['_trackEvent', 'Forecast Toggle', 'Click', 'BestForecast']);">BestForecast</a></li>
#   <li><a href="/cgi-bin/findweather/getForecast?setpref=EXPFCT&value=0&referer=%2fweather%2dforecast%2f97217" title="Use NWS" class="button " onclick="_gaq.push(['_trackEvent', 'Forecast Toggle', 'Click', 'NWS']);">NWS</a></li>
# </ul>
# <p><a href="/about/data.asp#differences">What's the difference?</a></p>
#   </ul>
#   </li>
#   <li class="gotMore">
#   <a href="javascript:void(0);" class="maps">Maps & Radar</a>
#   <ul class="sideSubNav">
#   <li class="sideGoBack"><a href="javascript:void(0);">Maps & Radar</a></li>
#   <li><a href="/weather-radar/" title="Radar Maps">Radar Maps</a></li>
#   <li><a href="/wundermap/?radar=1">Interactive Radar</a></li>
#   <li><a href="/wundermap/?sat=1">Interactive Satellite</a></li>
#   <li><a href="/wundermap/" title="WunderMap">WunderMap</a></li>
#   <li><a href="/maps/" title="Current Conditions Maps">Current Conditions Maps</a></li>
#   <li><a href="/ndfdimage/viewimage/" title="Forecast Maps">Forecast Maps</a></li>
#   <li><a href="/maps/catalog/" title="All Maps Catalog">Maps Catalog</a></li>
#   </ul>
#   </li>
#   <li class="gotMore">
#   <a href="javascript:void(0);" class="severe">Severe Weather</a>
#   <ul class="sideSubNav">
#   <li class="sideGoBack"><a href="javascript:void(0);">Severe Weather</a></li>
#   <li><a href="/severe.asp" title="U.S. Severe Weather Map">U.S. Severe Weather Map</a></li>
#   <li><a href="/severe/europe.asp" title="Europe Severe Weather Map">Europe Severe Weather Map</a></li>
#   <li><a href="/hurricane/" title="Hurricane &amp; Tropical Cyclones">Hurricane &amp; Tropical Cyclones</a></li>
#   <li><a href="/severeconvective.asp" title="Convective Outlook">Convective Outlook</a></li>
#   <li><a href="/wundermap?fire=1" title="Wildfires">Wildfires</a></li>
#   <li><a href="/prepare/" title="Preparedness">Preparedness</a></li>
#   <li><a href="/email/emailsettings.asp" title="Weather Alerts">Weather Alerts</a></li>
#   </ul>
#   </li>
#   <li class="gotMore">
#   <a href="javascript:void(0);" class="news">News &amp; Blogs<span class="new-badge-text-only live twiw">LIVE!</span></a>
#   <ul class="sideSubNav">
#   <li class="sideGoBack"><a href="javascript:void(0);">News &amp; Blogs</a></li>
#   <li><a href="/cat6" title="Category 6&trade;">Category 6&trade;</a></li>
#   <li><a href="/blog/" title="Blog Archive">Blog Archive</a></li>
#   <li><a href="/news/" title="Recent News Stories">Recent News Stories</a></li>
#   <li><a href="/weather-infographics/" title="Weather Infographics">Weather Infographics</a></li>
#   <li><a href="/weather-posters/" title="Weather Posters">Weather Posters</a></li>
#   </ul>
#   </li>
#   <li class="gotMore">
#   <a href="javascript:void(0);" class="photos">Photos &amp; Video</a>
#   <ul class="sideSubNav">
#   <li class="sideGoBack"><a href="javascript:void(0);">Photos &amp; Video</a></li>
#   <li><a href="/wximage/" title="WunderPhotos">WunderPhotos</a></li>
#   <li><a href="/webcams/" title="Webcams">Webcams</a></li>
#   <li><a href="/video/" title="Videos">Videos</a></li>
#   <li><a href="/wutv/" title="WUTV">WUTV</a></li>
#   </ul>
#   </li>
#   <li><a href="/history/" class="history" title="Historical Weather">Historical Weather</a></li>
#   <li class="gotMore">
#   <a href="javascript:void(0);" class="activities">Activities</a>
#   <ul class="sideSubNav">
#   <li class="sideGoBack"><a href="javascript:void(0);">Activities</a></li>
#   <li><a href="/ski/" title="Ski &amp; Snow Reports">Ski &amp; Snow Reports</a></li>
#   <li><a href="/marine-weather/" title="Marine Weather">Marine Weather</a></li>
#   </ul>
#   </li>
#   <li>
#   <a href="/sitemap/" class="browse">Site Map</a>
#   </li>
#   </ul>
#   <ul class="sidebar-footer">
#   <li><a href="/weatherstation/buyingguide.asp">Buy a Weather Station</a></li>
#   <li><a href="/personal-weather-station/signup">Add Weather Station</a></li>
#   <li><a href="/weatherstation/overview.asp">Weather Station Network</a></li>
#   <li><a href="/download" title="Weather Underground Mobile Apps">Mobile Apps</a></li>
#   <li><a href="/weather/api/" title="Weather API for Developers">Weather API for Developers</a></li>
#   </ul>
#   </div>
# </nav>
# 		<div class="header-ad-wrap">
# 	<center class="clearfix">
# 		<div id="WX_WindowShade"></div>
# 	</center>
# 		</div>
# 		<nav class="topbar">
# 	<div id="global-header" class="new-wu">
# 		<a href="javascript:void(0);" id="sidebarButton" class="right-off-canvas-toggle"><span class="fi-list-wrap"><i class="fi-list"></i></span></a>
# 		<a href="/" id="header-logo" class="logo" title="Weather Underground (10.226.240.36)"></a>
# 		<nav id="feature-menu" class="feature-menu">
#   <ul class="menu-list">
#   <li>
#   <label class="maps">Maps & Radar</label>
#   <ul class="menu-list">
#   <li><a href="/weather-radar/" title="Radar Maps">Radar Maps</a></li>
#   <li><a href="/wundermap/?radar=1">Interactive Radar</a></li>
#   <li><a href="/wundermap/?sat=1">Interactive Satellite</a></li>
#   <li><a href="/wundermap/" title="WunderMap">WunderMap</a></li>
#   <li><a href="/maps/" title="Current Conditions Maps">Current Conditions Maps</a></li>
#   <li><a href="/ndfdimage/viewimage/" title="Forecast Maps">Forecast Maps</a></li>
#   <li><a href="/maps/catalog/" title="All Maps Catalog">Maps Catalog</a></li>
#   </ul>
#   </li>
#   <li>
#   <label class="severe">Severe Weather</label>
#   <ul class="menu-list">
#   <li><a href="/severe.asp" title="U.S. Severe Weather Map">U.S. Severe Weather Map</a></li>
#   <li><a href="/severe/europe.asp" title="Europe Severe Weather Map">Europe Severe Weather Map</a></li>
#   <li><a href="/hurricane/" title="Hurricane &amp; Tropical Cyclones">Hurricane &amp; Tropical Cyclones</a></li>
#   <li><a href="/severeconvective.asp" title="Convective Outlook">Convective Outlook</a></li>
#   <li><a href="/wundermap?fire=1" title="Wildfires">Wildfires</a></li>
#   <li><a href="/prepare/" title="Preparedness">Preparedness</a></li>
#   <li><a href="/weather-alerts/" title="Weather Alerts">Email Alerts</a></li>
#   </ul>
#   </li>
#   <li>
#   <label class="news">News &amp; Blogs<span class="new-badge-text-only live twiw">LIVE!</span></label>
#   <ul class="menu-list">
#   <li><a href="/cat6" title="Category 6&trade;">Category 6&trade;</a></li>
#   <li><a href="/blog/" title="Blog Archive">Blog Archive</a></li>
#   <li><a href="/news/" title="Recent News Stories">Recent News Stories</a></li>
#   <li><a href="/weather-infographics/" title="Weather Infographics">Weather Infographics</a></li>
#   <li><a href="/weather-posters/" title="Weather Posters">Weather Posters</a></li>
#   </ul>
#   </li>
#   <li>
#   <label class="photos">Photos &amp; Video</label>
#   <ul class="menu-list">
#   <li><a href="/wximage/">WunderPhotos</a></li>
#   <li><a href="/webcams/">Webcams</a></li>
#   <li><a href="/video/">Videos</a></li>
#   <li><a href="/wutv/">WUTV</a></li>
#   </ul>
#   </li>
#   <li>
#   <label class="activities">Activities</label>
#   <ul class="menu-list">
#   <li><a href="/ski/">Ski &amp; Snow Reports</a></li>
#   <li><a href="/marine-weather/">Marine Weather</a></li>
#   </ul>
#   </li>
#   <li><a href="/weatherstation/buyingguide.asp">Buy a Weather Station</a></li>
#   <li><a href="/personal-weather-station/signup">Add Weather Station</a></li>
#   <li><a href="/weatherstation/overview.asp">Weather Station Network</a></li>
#   <li><a href="/history/">Historical Weather</a></li>
#   <li><a href="http://wundergroundstore.com">WU Store</a></li>
#   <li><a href="/download">Mobile Apps</a></li>
#   <li><a href="/forecast-flyer">Daily Forecast Flyer</a></li>
#   <li><a href="/weather/api/">Weather API for Developers</a></li>
#   <li><a href="/sitemap/">Site Map</a></li>
#   </ul>
# </nav>
# 		<div id="wuForm-contain" class="wu-form-contain">
# 		<form action="/cgi-bin/findweather/getForecast" name="wxsearch" id="wuForm" class="wu-form ui-front">
# 		<div id="wuSearch-contain" class="wu-search-contain">
# 		<input type="search" name="query" value="" id="wuSearch" class="wu-search" placeholder="Search Locations" data-autoinitialize="true" />
# 		<span class="close-search">
# 		<i class="fi-x-circle"></i>
# 		</span>
# 		<span class="geolocate-wrap">
# 		<i class="fi-target-two"></i>
# 		</span>
# 		</div>
# 		</form>
# 		</div>
# 		<div class="hide-for-small">
# 		<p class="wu-account" id="wuAccount"><a id="wu-member" href="/login.asp">Log in</a> | <a id="wu-member" href="/member/registration">Join</a></p>
# 		</a>
# 		<a href="#" data-dropdown="wuSettings-quick" id="wuSettings" class="wu-settings">
# 		<i class="fi-widget"></i>
# 		</a>
# 		</div>
# 		<div id="wuSettings-quick" data-dropdown-content class="wu-settings-quick f-dropdown content" >
# 		<ul class="button-group toggle radius">
#   <li><a onclick="wui.SetUnitToEnglish()" title="Switch to English" class="button selected">&deg;F</a></li>
#   <li><a onclick="wui.SetUnitToMetric()" title="Switch to Metric" class="button ">&deg;C</a></li>
# </ul>
# <ul class="button-group radius toggle compact forecast-type">
#   <li><a href="/cgi-bin/findweather/getForecast?setpref=EXPFCT&value=1&referer=%2fweather%2dforecast%2f97217" title="Use BestForecast" class="button selected" onclick="_gaq.push(['_trackEvent', 'Forecast Toggle', 'Click', 'BestForecast']);">BestForecast</a></li>
#   <li><a href="/cgi-bin/findweather/getForecast?setpref=EXPFCT&value=0&referer=%2fweather%2dforecast%2f97217" title="Use NWS" class="button " onclick="_gaq.push(['_trackEvent', 'Forecast Toggle', 'Click', 'NWS']);">NWS</a></li>
# </ul>
# <p><a href="/about/data.asp#differences">What's the difference?</a></p>
# 		<a href="/member/membersettings.html?page=prefs" id="wuSettings-more" class="wu-settings-more">More Settings</a>
# 		</div>
# 	</div>
# </nav>
# <script type="text/template" id="autocomplete_item_template">
# 	<% var defcon = (item.condition && item.condition.defcon) || 0; %>
# 	<% if (item.task=='geolocate') { %>
# 		<li class="geolocate-button"><div class="mimic-a"><span class="location-icon"><i class="fi-target-two"></i></span><%= item.name %></div></li>
# 	<% } else if (item.task=='headerGeolocate') { %>
# 		<li class="ui-autocomplete-geolocate"><div class="mimic-a menu-geolocate"><i class="fi-target-two"></i><%= item.name %></div></li>
# 	<% } else { %>
# 		<li class="needsclick needsfocus <% if (isCity) { %>is-city<% } %><% if (isFav) { %> is-fav<% } %><% if (hasConds && item.condition.severe) { %> is-severe defcon-<%= defcon %><% } %><% if (hasConds) { %> has-conds<% } %>">
# 		<a class="needsclick needsfocus">
# 		<% if (item.label) { %><span class="needsclick needsfocus city-name"><%= item.label %> <i class="needsclick needsfocus fi-<% if (defcon > 4) { %>info<% } else { %>alert<% } %>"></i></span><% } %>
# 		<% if (hasConds) { %>
# 		<span class="needsclick needsfocus city-conds">
# 		<%= item.condition.temperature %> &deg;F <%= item.condition.condition %>
# 		</span>
# 		<span class="needsclick needsfocus cond-icon-touch cond-set-<%= item.condition.iconPref %> cond-<%= item.condition.icon %>"></span>
# 		<% } %>
# 		<% if (isCity) { %><span class="needsclick needsfocus city-star" title="<% if (isFav) { %>Remove From<% } else { %>Add To<% } %> Favorite Cities"></span><% } %>
# 		</a>
# 		</li>
# 	<% } %>
# </script>
# 		<div id="inner-wrap">
# 		<div id="header-alert-bar" class="loading-bar"></div>
# 		<div class="favs-wrapper">
# 	<div id="favorites" class="favorites ">
# 		<div class="favorites-bar"></div>
# 		<input type="button" class="favorites-list-toggle" value="&#x25BC;" data-dropdown="favorites-list" />
# 		<div class="favorites-list f-dropdown" data-dropdown-content id="favorites-list"></div>
# 	</div>
# </div>
# <script type="text/template" id="favorites-city-template">
# 	<%
# 		var options = options || {};
# 		var isCity = true;
# 		var isFav = wui.favorites.is(city.zmw);
# 		var isHome = ''==city.zmw?true:false;
# 		//hasConds: (options.showConditions && !!(item.condition))
# 		var hasConds = !!(city.condition);
# 		var defcon = hasConds && city.condition.defcon ? city.condition.defcon : 5;
# 	%>
# 	<% if (city.zmw) { %>
# 		<li class="<% if (isCity) { %>is-city<% } %><% if (isFav) { %> is-fav<% } %><% if (hasConds && city.condition.severe) { %> is-severe defcon-<%= defcon %><% } %><% if (hasConds) { %> has-conds<% } %>" <% if (isCity) { %>data-zmw="<%= city.zmw %>" data-cityName="<%= city.name %>" <% } %>>
# 		<% if (options.label) { %><label><%= options.label %></label><% } %>
# 		<a href="<%= city.url %>/zmw:<%= city.zmw %>">
# 		<span class="city-name"><%= city.name %> <i class="fi-<% if (defcon > 4) { %>info<% } else { %>alert<% } %>"></i></span>
# 		<% if (hasConds) { %>
# 		<span class="city-conds">
# 		<%= city.condition.temperature %> &deg;F <%= city.condition.condition %>
# 		</span>
# 		<span class="cond-icon-touch cond-set-<%= city.condition.iconPref %> cond-<%= city.condition.icon %>"></span>
# 		<% } %>
# 		<% if (isCity) { %><span class="city-star" title="<% if (isFav) { %>Remove From<% } else { %>Add To<% } %> Favorite Cities"></span><% } %>
# 		<%
# 					//removing home button from list now that we have location management on the page - dxf
# 					if (isCity && 0) {
# 				%><span class="city-home <% if (isHome) { %> active <% }  %>" title="Set this as your Home City"</span><% } %>
# 	 </a>
# 		</li>
# 	<% } %>
# </script>
# <script type="text/template" id="favorites-bar-template">
# 	<ul class="no-bullet">
# 		<li><a href="/member/membersettings.html?page=favorites" title="Manage Favorites"><i class="fi-star"></i></a></li>
# 		<%
# 			if(favorites.length > 0) {
# 		_.each(favorites, function(city) {
# 		print(templateCity({
# 		city: city
# 		}));
# 		});
# 		} else {
# 		try {
# 		if(favCityList) {
# 		%>
# 		<li><a>Loading favorites...</a></li>
# 		<%
# 				}} catch(e) {}
# 			} %>
# 		<%
# 			if(favorites.length == 0) {
# 			%>
# 		<li class="popularCities-label">Popular <br/>Cities</li>
# 		<%
# 				_.each(popular, function(city, i) {
# 					print(templateCity({
# 						city: city,
# 					}));
# 				});
# 			}
# 			%>
# 	</ul>
# </script>
# <script type="text/template" id="favorites-list-template">
# 	<label>Popular Cities</label>
# 	<ul class="list-recents">
# 		<% _.each(popular, function(city) {
# 			print(templateCity({
# 				city: city
# 			}));
# 		}); %>
# 	</ul>
# </script>
# 		<section id="inner-content" class="inner-content" role="main">
# <div class="local-wx" id="city-page">
# 	<div class="wx-content">
# 		<div class="wx-col">
# 		<script type="text/template" id="station-label-template">
# 	<% var station = weather.current_observation.station; %>
# 	<span class="station-type <% if (weather.current_observation.source=="PWS") { %>is-pws<% } else { %>is-airport<% } %>"></span>
# 	<a href="<% if (weather.current_observation.source=="PWS") { %>/personal-weather-station/dashboard?ID=<%= station.id %>#history<% } else { %><%= weather.current_observation.history_url %><% } %>"><%= station.name %></a>
# </script>
# <div id="location">
# 		<h1 class="city-nav-header">
# 		Portland, OR
# 		<span class="trim-small">(97217)</span>
# 		<i class="fi-star favorite-star " data-zmw="97217.1.99999"></i>
# 		<dfn data-definition="Add/Remove home city location." class="no-decoration">
# 		<i class="fi-home homecity-button notHomepage" onclick="wui.favorites.home.toggle('97217.1.99999', this, 'isHomepage', 'notHomepage', 'Portland, OR');return false;"></i>
# 		</dfn>
# 		<i class="fi-list favorite-menu right-off-canvas-toggle none"></i>
# 		</h1>
# 		<div class="local-time"><i class="fi-clock"></i> <span>8:11 PM PDT on June 14, 2017</span> (GMT -0700)</div>
# 	<span id="station-label">
# 		<span class="station-type is-pws"></span>
# 		<a href="/personal-weather-station/dashboard?ID=KORPORTL592#history">
# 		Arbor Lodge Park
# 		</a>
# 	</span>
# 		<span id="report-link" >
# 		<span class="split">|</span>
# 		<a href="#" data-dropdown="report_box" aria-controls="report_box" aria-expanded="false"><span>Report</span></a>
# 		</span>
# 		<span class="split">|</span>
# 		<a href="javascript:void(0);" id="station-select-button">Change Station <span class="vert-icon arrow-icon"></span></a>
# 		<div id="report_box" class="report-box f-dropdown content" aria-hidden="true" aria-autoclose="false" tabindex="-1" data-dropdown-content>
# 		<h4>Report Station</h4>
# 		<p id="report-inactive" class="hide">Thank you for reporting this station. We will review the data in question.</p>
# 		<div id="report-active">
# 		<p id="report-error" class="error hide"></p>
# 		<p>You are about to report this weather station for bad data. Please select the information that is incorrect.</p>
# 		<form class="wuForm">
# 		<div class="checkbox-wrap">
# 		<input type="checkbox" name="badtemp" class="report-checkbox" id="badtemp" />
# 		<label for="badtemp">
# 		Temperature
# 		</label>
# 		</div>
# 		<div class="checkbox-wrap">
# 		<input type="checkbox" name="badpress" class="report-checkbox" id="badpress" />
# 		<label for="badpress">
# 		Pressure
# 		</label>
# 		</div>
# 		<div class="checkbox-wrap">
# 		<input type="checkbox" name="badwind" class="report-checkbox" id="badwind" />
# 		<label for="badwind">
# 		Wind
# 		</label>
# 		</div>
# 		<div class="checkbox-wrap">
# 		<input type="checkbox" name="badfct" class="report-checkbox" id="badfct" />
# 		<label for="badfct">
# 		Forecast
# 		</label>
# 		</div>
# 		<div class="checkbox-wrap">
# 		<input type="checkbox" name="badoff" class="report-checkbox" id="badoff" />
# 		<label for="badoff">
# 		Station Offline
# 		</label>
# 		</div>
# 		</form>
# 		<div class="submit-button">
# 		<button id="flagstationbutton" class="radius">Send Report</button>
# 		</div>
# 		</div>
# 		</div>
# 		<div ng-controller="twc_wu_station_select_controller" id="twc_wu_station_select_controller">
# 	 <a id="station-select-button-ng" ng-show="stationSelectActive"
# 		ng-click="onChangeStationTrigger()"
# 		ng-class="{open: stationSelectVisible}">
# 	</a>
#   <div id="stationselector" class="ng-cloak" ng-class="{open: selectionActive}">
# 	<span class="close hide">
# 		<span>Close</span>
# 		<i class="fi-x"></i>
# 	</span>
# 	<div id="stationselector_loading" ng-class="selectionLoading? 'loading' : ''"></div>
# 	<div id="stationselector_content" class="row collapse" twc-wu-station-select-accordion="selectionActive">
# 		<div class="small-12 medium-6 large-4 columns">
# 		<div id="stationselector_map" on-map-update="updateStations()"
# 				twc-wu-station-select-map-visible="selectionActive"
# 				twc-wu-station-select-map-on-hover="onStationMapHover($stationId)"
# 				twc-wu-station-select-map-on-leave="onStationMapLeave($stationId)"
# 				twc-wu-station-select-map-on-click="onStationClick($stationId)"
# 				twc-wu-station-select-map-on-fetch="onFetch($options)"
# 				twc-wu-station-select-map-station-active="stationActive"
# 				twc-wu-station-select-map-info="mapInfo"
# 				twc-wu-station-select-map="mapConfig"></div>
# 		<div id="stationselector_toomany" ng-show="hasTooManyStations">
# 		<p>
# 		<a ng-href="/wundermap/?lat={{ mapInfo.lat }}&lon={{ mapInfo.lon }}&zoom={{ mapInfo.zoom }}&wxsn=1">See more</a>
# 		</p>
# 		<p>(<a ng-click="reset()" class="map-reset"></a>Reset Map)</p>
# 		</div>
# 		</div>
# 		<div class="small-12 medium-6 large-8 columns">
# 		<div class="row collapse">
# 		<div class="small-12 medium-12 large-4 large-push-8 columns">
# 		<div class="current-container">
# 		<div class="title">Current Station</div>
# 		<div id="stationselector_current">
# 		<div ng-if="isPWS" class="station-type is-pws">Personal Weather Station</div>
# 		<div ng-if="!isPWS" class="station-type is-airport">Airport</div>
# 		<div class="station-name" ng-switch="current_observation.source">
# 		<a ng-switch-when="PWS"
# 									ng-href="/personal-weather-station/dashboard?ID={{ current_observation.station.id }}#history">
# 		{{ current_observation.station.neighborhood ? current_observation.station.neighborhood : '' }}
# 		<span class="station-id">{{ current_observation.station.neighborhood ? current_observation.station.neighborhood : current_observation.station.name }}({{ current_observation.station.id }})</span>
# 		</a>
# 		<a ng-switch-when="HDFSYNOP" ng-href="/history/station/
# 									{{ current_location.wmo }}/
# 									{{ current_time.year }}/
# 									{{ current_time.month }}/
# 									{{ current_time.day }}/
# 									DailyHistory.html">
# 		{{ current_observation.name ? current_observation.name : current_observation.city }}
# 		<span class="station-id">({{ current_observation.station.id }})</span>
# 		</a>
# 		<a ng-switch-default ng-href="/history/airport/
# 									{{ current_observation.station.id }}/
# 									{{ current_time.year }}/
# 									{{ current_time.month }}/
# 									{{ current_time.day }}/
# 									DailyHistory.html">
# 		{{ current_observation.station.name ? current_observation.station.name : current_observation.station.city }}
# 		<span class="station-id">({{ current_observation.station.id }})</span>
# 		</a>
# 		</div>
# 		<div class="station-location">
# 		<span>Location</span>:
# 		<strong class="location-data">
# 		<span class="station-city">{{ current_observation.station.city }}</span>,
# 		<span class="station-state">{{ current_observation.station.state }}</span>
# 		</strong>
# 		<div class="wx-data">
# 		<span>Elevation</span>:
# 		<span class="wx-value">{{ current_observation.station.elevation }}</span>
# 		<span class="wx-unit">{{ labels.elevation.units }}</span>
# 		</div>
# 		</div>
# 		</div>
# 		</div>
# 		</div>
# 		<div class="small-12 medium-12 large-8 large-pull-4 columns">
# 		<div class="list-container">
# 		<div class="title">Nearby Weather Stations</div>
# 		<div id="stationselector_nostations" ng-hide="stations.length">
# 		<p>There are no personal weather stations in this area.</p>
# 		<p>
# 		<a ng-click="reset()" class="map-reset">Reset the map</a>
# 		or
# 		<a href="/weatherstation/setup.asp">add your own Personal Weather Station.</a>.
# 		</p>
# 		<a href="javascript:void(0);" class="hide map-zoom-out"></a>
# 		</div>
# 		<div id="stationselector_list"
# 							ng-show="stations.length"
# 							twc-wu-station-select-scroll-refresh="stations"
# 							twc-wu-station-select-scroll="selectionActive">
# 		<table id="stationselector_table">
# 		<tbody>
# 		<tr ng-repeat="station in stations | orderBy:'_distance'"
# 										ng-class="{'is-pws': station.isPWS, 'is-airport': !station.isPWS, 'ext-link': station.isExternal}">
# 		<td>
# 		<span class="station-icon"></span>
# 		</td>
# 		<td>
# 		<a class="stationselectorRowPWS" href="" title=""
# 												ng-class="{hover: station.isFocus, selected: station.id === current_observation.station.id}"
# 												ng-mouseover="onStationHover(station.id)"
# 												ng-mouseleave="onStationLeave(station.id)"
# 												ng-click="onStationClick(station)"
# 												>
# 		{{ station.neighborhood ? station.neighborhood : station.name }}
# 		({{ station.id }})
# 		</a>
# 		</td>
# 		<td>
# 		<span class="temp">{{ station.temperature }}</span>&deg;
# 		</td>
# 		</tr>
# 		</tbody>
# 		</table>
# 		</div>
# 		<div id="stationselector_list_footer" ng-show="Scroll.canScroll">
# 		<!--<div class="scroll-fade"></div>-->
# 		<span>
# 		<span>Showing</span>
# 		{{ stations.length }}
# 		<span>Stations</span>
# 		</span>
# 		<span class="list-scroll-arrow list-scroll-up"
# 								ng-click="Scroll.up()"
# 								ng-class="{disabled: !Scroll.canScrollUp}"></span>
# 		<span class="list-scroll-arrow list-scroll-down"
# 								ng-click="Scroll.down()"
# 								ng-class="{disabled: !Scroll.canScrollDown}"></span>
# 		</div>
# 		</div>
# 		</div>
# 		</div>
# 		</div>
# 	</div>
# </div>
# </div>
# 		<!--<div id="stationselector">
# 	<span class="close hide">
# 		CLOSE <i class="fi-x"></i>
# 	</span>
# 	<div id="stationselector_loading"></div>
# 	<div id="stationselector_content" class="row collapse">
# 		<div class="small-12 medium-6 large-4 columns">
# 		<div id="stationselector_map"></div>
# 		<div id="stationselector_toomany"></div>
# 		</div>
# 		<div class="small-12 medium-6 large-8 columns">
# 		<div class="row collapse">
# 		<div class="small-12 medium-12 large-4 large-push-8 columns">
# 		<div class="current-container">
# 		<div class="title">Current Station</div>
# 		<div id="stationselector_current">
# 		<div class="station-type is-pws">Personal Weather Station</div>
# 		<div class="station-name">
# 		<a href="/personal-weather-station/dashboard?ID=KORPORTL592">
# 		Arbor Lodge Park <span class="station-id">(KORPORTL592)</span>
# 		</a>
# 		</div>
# 		<div class="station-location">
# 		Location:
# 		<strong><span class="station-city">Portland</span>, <span class="station-state">OR</span></strong>
# 		<div class="wx-data">
# 		Elevation:
# 		<span class="wx-value">170</span>
# 		<span class="wx-unit">ft</span>
# 		</div>
# 		</div>
# 		</div>
# 		</div>
# 		</div>
# 		<div class="small-12 medium-12 large-8 large-pull-4 columns">
# 		<div class="list-container">
# 		<div class="title">Nearby Weather Stations</div>
# 		<div id="stationselector_nostations"></div>
# 		<div id="stationselector_list">
# 		<table id="stationselector_table">
# 		</table>
# 		</div>
# 		<div id="stationselector_list_footer"></div>
# 		</div>
# 		</div>
# 		</div>
# 		</div>
# 	</div>
# </div>
# <script type="text/template" id="stationselector_table_template">
# 	<tbody>
# 	<% _.each(stations, function(station) { %>
# 		<%
# 			var isPWS = (station.type == 'PWS');
# 			var query = (isPWS ? 'pws:' : '') + station.id;
# 			var isExternal = (radius && station._distance > radius);
# 		var classNames = [];
# 		classNames.push(isPWS ? 'is-pws' : 'is-airport');
# 		if (isExternal) { classNames.push('ext-link'); }
# 		var classNamesStr = classNames.join(' ');
# 		var title = station._title + ' (' + station.id + ')';
# 		%>
# 		<tr class="<%= classNamesStr %>">
# 		<td><span class="station-icon"></span></td>
# 		<td><a class="stationselectorRowPWS" data-station="<%= station.id %>" href="/cgi-bin/findweather/getForecast?query=<%= query %>" title=""><%= title %></a></td>
# 		<td><span class="temp"><%= station.temperature %></span>&deg;</td>
# 		</tr>
# 	<% }); %>
# 	</tbody>
# </script>
# <script type="text/template" id="stationselector_list_footer_template">
# 	<div class="scroll-fade"></div>
# 	<span>Showing <%= stations.length %> Stations</span>
# 	<span class="list-scroll-arrow list-scroll-up"></span>
# 	<span class="list-scroll-arrow list-scroll-down"></span>
# </script>
# <script type="text/template" id="stationselector_nostations_template">
# 	<p>There are no personal weather stations in this area.</p>
# 	<p><a href="javascript:void(0);" class="map-reset">Reset the map</a>, or <a href="/weatherstation/setup.asp">add your own Personal Weather Station</a>.</p>
# 	<a href="javascript:void(0);" class="hide map-zoom-out">zoom out</a>
# </script>
# <script type="text/template" id="stationselector_toomany_template">
# 	<% var querystring = jQuery.param({lat: mapOptions.center.lat(), lon: mapOptions.center.lng(), zoom: mapOptions.zoom, wxsn: 1}); %>
# 	<p><a href="/wundermap/?<%= querystring %>">See more weather stations with the WunderMap!</a></p>
# 	<p>(<a href="javascript:void(0);" class="map-reset">Reset the Map</a>)</p>
# </script>
# <script type="text/template" id="stationselector_current_template">
# 	<%
# 		var current_observation = weather.current_observation;
# 		var station = current_observation.station;
# 		var isPWS = (current_observation.source == 'PWS');
# 	%>
# 	<% if (isPWS) { %>
# 		<div class="station-type is-pws"><%= labels.pws.label %></div>
# 	<% } else { %>
# 		<div class="station-type is-airport"><%= labels.airport.label %></div>
# 	<% } %>
# 	<div class="station-name">
# 		<a href="<%= current_observation.history_url %>">
# 		<% if (isPWS && station.name) { %>
# 		<%= station.name %> <span class="station-id">(<%= station.id %>)</span>
# 		<% } else if (isPWS) { %>
# 		<span class="station-id"><%= station.id %></span>
# 		<% } else { %>
# 		<%= station.name || station.city %> <span class="station-id">(<%= station.id %>)</span>
# 		<% } %>
# 		</a>
# 	</div>
# 	<div class="station-location">
# 		Location:
# 		<strong><span class="station-city"><%= station.city %></span>, <span class="station-state"><%= station.state || station.country_name%></span></strong>
# 		<div class="wx-data">
# 		<%= labels.elevation.label %>:
# 		<span class="wx-value"><%= station.elevation %></span>
# 		<span class="wx-unit"><%= labels.elevation.units %></span>
# 		</div>
# 	</div>
# </script>
# -->
# </div>
# <div class="row collapse city-nav">
#   <div class="columns">
#   <div class="subnav-contain">
#   <ul class="subnav">
#   <li><a href="/us/or/portland/zmw:97217.1.99999" id="city-nav-forecast" class="selected">Forecast</a></li>
#   <li><a href="/history/airport/KVUO/2017/06/14/DailyHistory.html?req_city=Portland&req_state=OR&reqdb.zip=97217&reqdb.magic=1&reqdb.wmo=99999" id="city-nav-history" >History</a></li>
#   <li><a href="/history/airport/KVUO/2017/6/14/MonthlyCalendar.html?req_city=Portland&req_state=OR&reqdb.zip=97217&reqdb.magic=1&reqdb.wmo=99999#calendar" id="city-nav-calendar" >Calendar</a></li>
#   <li><a href="/us/or/portland/zmw:97217.1.99999/precipitation" id="city-nav-precipitation" >Rain / Snow</a></li>
#   <li><a href="/us/or/portland/zmw:97217.1.99999/health" id="city-nav-health" >Health</a></li>
#   </ul>
#   </div>
#   <div class="subnav">
#   <a href="#" data-dropdown="subnav-dropdown" class="button split radius">
#   Forecast
#   <span data-dropdown="subnav-dropdown"><i class="fi-list"></i></span>
#   </a>
#   <ul id="subnav-dropdown" class="f-dropdown" data-dropdown-content>
#   <li><a href="/us/or/portland/zmw:97217.1.99999" id="city-nav-forecast" class="selected">Forecast</a></li>
#   <li><a href="/history/airport/KVUO/2017/06/14/DailyHistory.html?req_city=Portland&req_state=OR&reqdb.zip=97217&reqdb.magic=1&reqdb.wmo=99999" id="city-nav-history" >History</a></li>
#   <li><a href="/history/airport/KVUO/2017/6/14/MonthlyCalendar.html?req_city=Portland&req_state=OR&reqdb.zip=97217&reqdb.magic=1&reqdb.wmo=99999#calendar" id="city-nav-calendar" >Calendar</a></li>
#   <li><a href="/us/or/portland/zmw:97217.1.99999/precipitation" id="city-nav-precipitation" >Rain / Snow</a></li>
#   <li><a href="/us/or/portland/zmw:97217.1.99999/health" id="city-nav-health" >Health</a></li>
#   </ul>
#   </div>
#   </div>
# </div>
# 	<div class="alert-bar defcon-5 defcon-basic">
# 		<i class="fi-info"></i>
# 		<div class="alert-items">
# 		<span>Active Advisory:</span>
# 	 <a href="/US/OR/006.html#SPE" class="">Special Statement</a>
# 		</div>
# 	</div>
# <div id="current" class="row">
# 	<div class="small-12 medium-6 large-4 columns cc1" id="cc1">
# 		<div class="row">
# 		<div class="small-12 columns">
# 		<h2>
# 		<span class="wx-data" data-station="KORPORTL592" data-variable="station.elevation">
# 		Elev
# 		<span class="wx-value">170</span>
# 		<span class="wx-unit">ft</span>
# 		</span>
# 		<span class="wx-data" data-station="KORPORTL592" data-variable="station.latitude">
# 		<span class="wx-data"><span class="wx-value">45.57</span>
# 		<span class="wx-unit">&deg;N</span></span>,
# 		</span>
# 		<span class="wx-data" data-station="KORPORTL592" data-variable="station.longitude">
# 		<span class="wx-data"><span class="wx-value">122.69</span>
# 		<span class="wx-unit">&deg;W</span></span>
# 		</span>
# 		<span class="split">|</span>
# 		Updated
# 		<span id="update-time">47 seconds ago</span>
# 		</h2>
# 		</div>
# 		<div class="small-3 columns">
# 		<div id="curIcon"><img src="//icons.wxug.com/i/c/v4/partlycloudy.svg" alt="Partly Cloudy" class="wx-data" data-station="KORPORTL592" data-variable="icon_url" /></div>
# 		<div id="curCond" class="wx-data" data-station="KORPORTL592" data-variable="condition"><span class="wx-value">Partly Cloudy</span></div>
# 		</div>
# 		<div class="small-6 columns">
# 		<div id="curTemp" style="color: #feae3c;">
# 	<span class="wx-data" data-station="KORPORTL592" data-variable="temperature">
# 		<span class="wx-value">65.4</span>
# 		<span class="wx-unit">&deg;F</span>
# 	</span>
# 		</div>
# 		<div id="curFeel">
# 		<span class="wx-label">Feels Like</span>
# 		<span style="color: #feae3c;">
# 	<span class="wx-data" data-station="KORPORTL592" data-variable="feelslike">
# 		<span class="wx-value">65.4</span>
# 		<span class="wx-unit">&deg;F</span>
# 	</span>
# 		</span>
# 		</div>
# 		</div>
# 		<div class="small-3 columns">
# 		<div id="curWind">
# 		<div id="windCompassContainer">
# 		<div id="windCompass" class="wx-data" data-station="KORPORTL592" data-variable="wind_dir_degrees" data-update-effect="wind-compass" style="transform:rotate(232deg);-ms-transform:rotate(232deg);-webkit-transform:rotate(232deg);">
# 		<div class="dial">
# 		<div class="arrow-direction"></div>
# 		</div>
# 		</div>
# 		<div id="windN">N</div>
# 		<div id="windCompassSpeed" class="wx-data" data-station="KORPORTL592" data-variable="wind_speed">
# 		<span class="wx-value">1.2</span>
# 		</div>
# 		</div>
# 		</div>
# 		<div id="windDir">
# 		<span class="wx-data " data-station="KORPORTL592" data-variable="wind_dir">
# 		<span class="is-variable">Wind Variable</span>
# 		<span class="not-variable">Wind from <span class="wx-value">SW</span></span>
# 		</span>
# 		<span class="wx-data" data-station="KORPORTL592" data-variable="wind_gust_speed"><br />Gusts
# 	<span class="wx-data" data-station="KORPORTL592" data-variable="wind_gust_speed">
# 		<span class="wx-value">2.2</span>
# 		<span class="wx-unit">mph</span>
# 	</span>
# </span>
# 		</div>
# 		</div>
# 		</div>
# <div id="wx-quickie" class="wx-data" data-station="KORPORTL592" data-variable="weather_quickie">
# 	<p id="precip-inline"></p>
# 	<p class="wx-value">
# 	</p>
# </div>
# 		<div class="row collapse" id="todaySummary">
# 		<div class="small-6 columns">
# 		<span class="today" title="Today's weather summary for <%= station.name %>">Today<span>
# 		<div>High -- <span class="split">|</span> Low -- &deg;F</div>
# 		<div>--% Chance of Precip.</div>
# 		</div>
# 		<div class="small-6 columns">
# 		<a href="/personal-weather-station/dashboard?ID=<%= station.id %>#history/s<%= yesterday_datestr %>/e<%= yesterday_datestr %>/mdaily" title="Yesterday's weather summary for <%= station.name %>">Yesterday</a>
# 		<div>High -- <span class="split">|</span> Low -- &deg;F</div>
# 		<div>
# 		Precip. -- in
# 		</div>
# 		</div>
# 		</div>
# 		<div id="precip-above" class="row hook-wrap hook-test">
# 		</div>
# 		<div id="pollen-hook" class="row hook-wrap hook-test">
# 		</div>
# 		<div id="uv-hook" class="row hook-wrap hook-test">
# 		</div>
# 		<div id="alerts-hook" class="row hook-wrap alert-severe">
# 		<div class="columns small-12">
# 		<div class="alerts-message defcon-5">
# 		<p>
# 		<a href="#" data-reveal-id="alerts-sign-up">
# 		<i class="fi-icon fi-alert"></i>
# 		Sign up for Severe Weather Alerts in your area
# 		</a>
# 		</p>
# 		</div>
# 		</div>
# 		</div>
# 		<div id="vote-hook" class="row hook-wrap hook-test">
# 		</div>
# 		<div class="ccDetails">
# 		<input type="checkbox" id="condition-table-state" class="show-more-state">
# <table cellpadding="0" cellspacing="0" class="cc3">
# 	<tr>
# 		<td><dfn>Pressure</dfn></td>
# 		<td>
# 		<span class="pSteady">
# 	<span class="wx-data" data-station="KORPORTL592" data-variable="pressure">
# 		<span class="wx-value">30.05</span>
# 		<span class="wx-unit">in</span>
# 	</span>
# 		</span>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td><dfn>Visibility</dfn></td>
# 		<td>
# 	<span class="wx-data" data-station="KORPORTL592" data-variable="visibility">
# 		<span class="wx-value">10.0</span>
# 		<span class="wx-unit">miles</span>
# 	</span>
# </td>
# 	</tr>
# 	<tr>
# 		<td>Clouds</td>
# 		<td>
# 	<span class="wx-data-BUGBUG-NOT-DONE" data-station="KORPORTL592" data-variable="cloud_description">
# 		<span class="wx-value">
# 		Clear
# 		</span>
# 	</span>
# <br /></td>
# 	</tr>
# 	<tr>
# 		<td><dfn>Dew Point</dfn></td>
# 		<td>
# 	<span class="wx-data" data-station="KORPORTL592" data-variable="dewpoint">
# 		<span class="wx-value">49</span>
# 		<span class="wx-unit">&deg;F</span>
# 	</span>
# </td>
# 	</tr>
# 	<tr>
# 		<td><dfn>Humidity</dfn></td>
# 		<td>
# 	<span class="wx-data" data-station="KORPORTL592" data-variable="humidity">
# 		<span class="wx-value">55</span><span class="wx-unit">%</span>
# 	</span>
# </td>
# 	</tr>
# 	<tr>
# 		<td>Rainfall</td>
# 		<td>
# 	<span class="wx-data" data-station="KORPORTL592" data-variable="precip_today">
# 		<span class="wx-value"> 0.00</span>
# 		<span class="wx-unit">in </span>
# 	</span>
# </td>
# 	</tr>
# 	<tr>
# 		<td><dfn>Snow Depth</dfn></td>
# 		<td>
# 		<span class="wx-na">Not available.</span>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td colspan="2">
# 		<div class="row collapse astronomy-data" id="curAstronomy">
# 		<div class="columns">
# 		<a href="/sky/ShowSky.asp?CurDir=Up&TheLat=45.56999969&TheLon=-122.69000244&TimeZoneName=America/Los_Angeles" title="Sunrise, sunset, and astronomy for Portland">Sun &amp; Moon</a>
# 		</div>
# 		<div class="small-6 columns sun">
# 		<span class="rise"><span class="astro-data" id="cc-sun-rise">5:21</span> <span class="ampm">AM</span></span>
# 		<span class="set"><span class="astro-data" id="cc-sun-set">9:01</span> <span class="ampm">PM</span></span>
# 		</div>
# 		<div class="small-6 columns moon">
# 		<div class="moonNorth">
# 		<span class="astro-data p-waninggibbous" id="cc-moon-phase"></span>
# 		<strong>Waning Gibbous,</strong>
# 		<span class="nobr"><strong>73</strong>% visible</span>
# 		</div>
# ...
# {
# 	"response": {
# 		"version": "2.0",
# 		"units": "english",
# 		"termsofService": "https://www.wunderground.com/weather/api/d/terms.html",
# 		"attribution": {
# 		"image":"//icons.wxug.com/graphics/wu2/logo_130x80.png",
# 		"title":"Weather Underground",
# 		"link":"http://www.wunderground.com"
# 		},
# 		"features": {
# 		"conditions": 1
# 		}
# 		, "location": {
# 		"name": "Portland",
# 		"neighborhood":null,
# 		"city": "Portland",
# 		"state": "OR",
# 		"state_name":"Oregon",
# 		"country": "US",
# 		"country_iso3166":null,
# 		"country_name":"USA",
# 		"continent":"US",
# 		"zip":"97217",
# 		"magic":"1",
# 		"wmo":"99999",
# 		"radarcode":"rtx",
# 		"radarregion_ic":"rdm",
# 		"radarregion_link": "/or/redmond",
# 		"latitude":45.56999969,
# 		"longitude":-122.69000244,
# 		"elevation":177,
# 		"l": "/q/zmw:97217.1.99999",
# 		"canonical": "/us/or/portland"
# 		},
# 		"date": {
# 	"epoch": 1497496270,
# 	"pretty": "8:11 PM PDT on June 14, 2017",
# 	"rfc822": "Wed, 14 Jun 2017 20:11:10 -0700",
# 	"iso8601": "2017-06-14T20:11:10-0700",
# 	"year": 2017,
# 	"month": 6,
# 	"day": 14,
# 	"yday": 164,
# 	"hour": 20,
# 	"min": "11",
# 	"sec": 10,
# 	"monthname": "June",
# 	"monthname_short": "Jun",
# 	"weekday": "Wednesday",
# 	"weekday_short": "Wed",
# 	"ampm": "PM",
# 	"tz_short": "PDT",
# 	"tz_long": "America/Los_Angeles",
# 	"tz_offset_text": "-0700",
# 	"tz_offset_hours": -7.00
# }
# 	}
# 		,
# 	"current_observation": {
# 		"source": "PWS",
# 		"station": {
# 		"id":"KORPORTL592",
# 		"name":"Arbor Lodge Park",
# 		"city":"Portland",
# 		"state":"OR",
# 		"state_name":"Oregon",
# 		"country":"US",
# 		"country_name":"USA",
# 		"country_iso3166":"US",
# 		"latitude":45.573681,
# 		"longitude":-122.691711,
# 		"elevation":170
# 		},
# 		"estimated": null,
# 		"date": {
# 	"epoch": 1497496224,
# 	"pretty": "8:10 PM PDT on June 14, 2017",
# 	"rfc822": "Wed, 14 Jun 2017 20:10:24 -0700",
# 	"iso8601": "2017-06-14T20:10:24-0700",
# 	"year": 2017,
# 	"month": 6,
# 	"day": 14,
# 	"yday": 164,
# 	"hour": 20,
# 	"min": "10",
# 	"sec": 24,
# 	"monthname": "June",
# 	"monthname_short": "Jun",
# 	"weekday": "Wednesday",
# 	"weekday_short": "Wed",
# 	"ampm": "PM",
# 	"tz_short": "PDT",
# 	"tz_long": "America/Los_Angeles",
# 	"tz_offset_text": "-0700",
# 	"tz_offset_hours": -7.00
# },
# 		"metar": "METAR KVUO 150253Z AUTO 31004KT 10SM CLR 18/08 A3004 RMK AO2 SLP174 T01780083 56012",
# 		"condition":"Partly Cloudy",
# 		"temperature": 65.4,
# 		"humidity":55,
# 		"wind_speed":1.2,
# 		"wind_gust_speed":2.2,
# 		"wind_dir":"SW",
# 		"wind_dir_degrees":232,
# 		"wind_dir_variable":0,
# 		"pressure": 30.05,
# 		"pressure_trend": "0",
# 		"pressure_tendency": -0.013334,
# 		"pressure_tendency_string": "Decreasing",
# 		"dewpoint": 49,
# 		"heatindex": null,
# 		"windchill": null,
# 		"feelslike": 65.4,
# 		"visibility":10.0,
# 		"cloud_description": {
# 		"highest_layer": "CLR",
# 		"oktas": 0,
# 		"layers": [
# 		{
# 		"height": null,
# 		"height_char": null,
# 		"cover": "CLR",
# 		"cover_text": "Clear",
# 		"oktas": "0",
# 		"other": null
# 		}
# 		]
# 		},
# 		"solarradiation": null,
# 		"uv_index": 0,
# 		"temperature_indoor": null,
# 		"humidity_indoor": null,
# 		"t1f": null,
# 		"t2f": null,
# 		"precip_1hr":0.00,
# 		"precip_today":0.00,
# 		"soil_temp": null,
# 		"soil_moisture": null,
# 		"leaf_wetness": null,
# 		"icon":"partlycloudy",
# 		"icon_url":"//icons.wxug.com/i/c/v4/partlycloudy.svg",
# 		"forecast_url":"http://www.wunderground.com/US/OR/Portland.html",
# 		"history_url":"http://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KORPORTL592",
# 		"ob_url":"http://www.wunderground.com/cgi-bin/findweather/getForecast?query=45.573681,-122.691711",
# 		"nowcast":"",
# 		"pollen": 0.40,
# 		"flu": null,
# 		"ozone_index": null,
# 		"ozone_text": null,
# 		"pm_index": null,
# 		"pm_text": null,
# 		"yesterday_max_temperature": 64.5,
# 		"yesterday_min_temperature": 51.1,
# 		"yesterday_precip_total": 0.0,
# 		"cod_wspd": null,
# 		"cod_mslp": null,
# 		"cod_feels_like": null,
# 		"cod_vis": null,
# 		"cod_altimeter": null,
# 		"cod_rh": null,
# 		"cod_temp_min_24hour": null,
# 		"cod_snow_season": null,
# 		"cod_precip_mtd": null,
# 		"cod_snow_6hour": null,
# 		"cod_temp_max_24hour": null,
# 		"cod_temp_change_24hour": null,
# 		"cod_wc": null,
# 		"cod_snow_24hour": null,
# 		"cod_snow_ytd": null,
# 		"cod_hi": null,
# 		"cod_pchange": null,
# 		"cod_snow_1hour": null,
# 		"cod_snow_mtd": null,
# 		"cod_precip_1hour": null,
# 		"cod_snow_2day": null,
# 		"cod_snow_3day": null,
# 		"cod_precip_2day": null,
# 		"cod_snow_7day": null,
# 		"cod_precip_3day": null,
# 		"cod_precip_6hour": null,
# 		"cod_precip_24hour": null,
# 		"cod_precip_ytd": null,
# 		"cod_precip_7day": null
# 	}
# }
# ;
# </script>
# 	<script src="//icons.wxug.com/scripts/wui-whyads/advert.js?0.0.3"></script>
# <script>
# 	(function () {
# 		var fromPrefToBoolean = function(pref, default_val) {
# 		if (pref === "1" || pref === 1 || pref === "true" || pref === true) {
# 		return true;
# 		} else if (pref === "0" || pref === 0 || pref === "false" || pref === false) {
# 		return false;
# 		} else {
# 		return default_val;
# 		}
# 		}
# 		wui.build_url = function(options) {
# 		var url = '//api-ak-aws.wunderground.com/api/' + options.k;
# 		if (options.features) {
# 		url += '/' + options.features.join('/');
# 	 if ("history" in options.features) { url.replace("/history/","/history_"+wui.date.strftime('%Y%m%d')+"/"); }
# 		}
# 		if (options.lang) {
# 		url += '/lang:' + options.lang;
# 		}
# 		if (options.units) {
# 		url += '/units:' + options.units;
# 		}
# 		if (options.version) {
# 		url += '/v:' + options.version;
# 		}
# 		if (options.bestfct == 0 || options.bestfct == false) {
# 		url += '/bestfct:0';
# 		}
# 		if (options.bestfct == 1 || options.bestfct == true) {
# 		url += '/bestfct:1';
# 		}
# 		url += '/q/'+ options.query +'.json';
# 		url += '?ttl=300';
#   if (options.fodqa) {
#   url += '&qa=1&fod=1';
#   }
# 		if(options.selected_pws) {
# 		url += '&sp=' + options.selected_pws;
# 		}
# 		return url;
# 		}
# 		var initScripts = [
# 		{
# 		load: "//ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js",
# 		complete: function () {
# 		if ( window.jQuery && wui.bootstrapped.pageType == "CityPage" ) {
# 		//Load API data for city page
# 		var prefs = wui.bootstrapped.prefs;
# 		var query = 'zmw:' + '97217.1.99999';
# 		var selected_pws = wui.bootstrapped.prefs.selected_pws;
# 		var citypage_options = {
# 		k: 'c991975b7f4186c0',
# 		bestfct: fromPrefToBoolean(prefs['EXPFCT'], true),
# 		lang: prefs['LangCode'],
# 		features: [ 'forecast10day',
# 		'hourly10day',
# 		'labels',
# 		//'conditions',
# 		'astronomy10day'],
# 		selected_pws: selected_pws,
# 		query: query,
#   fodqa: false,
# 		units: prefs['Units'],
# 		version: '2.0'
# 		};
# 		var url = wui.build_url(citypage_options);
# 		var ajaxOptions = {
# 		async: true,
# 		cache: true,
# 		dataType: "jsonp",
# 		jsonpCallback: 'weatherCallback',
# 		url: url
# 		};
# 		wui.api_done = $.ajax(ajaxOptions).done(function(data) {
# 		wui.api_data = $.extend({}, wui.api_data, data);
# 		});
# 		}
# 		}
# 		},
# 		"//ajax.googleapis.com/ajax/libs/jqueryui/1.10.4/jquery-ui.min.js",
# 		"//icons.wxug.com/scripts/wui-js/2.0.2/wui.min.js",
# 		"//cdnjs.cloudflare.com/ajax/libs/foundation/5.5.0/js/foundation.min.js",
# 		"//cdnjs.cloudflare.com/ajax/libs/underscore.js/1.4.4/underscore-min.js",
# 		"//cdnjs.cloudflare.com/ajax/libs/backbone.js/1.1.0/backbone-min.js",
# 		"//cdnjs.cloudflare.com/ajax/libs/flot/0.8.2/jquery.flot.min.js",
# 		"//cdnjs.cloudflare.com/ajax/libs/flot/0.8.2/jquery.flot.time.min.js",
# 		"//icons.wxug.com/scripts/backbone-nested/1.1.2/backbone-nested.min.js",
# 		"//icons.wxug.com/scripts/responsive-tables.js",
#   "//icons.wxug.com/scripts/tablesaw/1.0.4/tablesaw.min.js",
#   "//icons.wxug.com/scripts/pubnation.js",
# 		"//icons.wxug.com/scripts/wui-backbone/1.7.4/wui.backbone.min.js",
# 		"//icons.wxug.com/scripts/rAF/0.0.1/rAF.min.js",
# 		"//icons.wxug.com/scripts/wui-flot/0.1.5/wui.flot.min.js",
# 		"//cdnjs.cloudflare.com/ajax/libs/jquery-ajaxtransport-xdomainrequest/1.0.3/jquery.xdomainrequest.min.js", // for IE cors support
# 		"//icons.wxug.com/scripts/wui-citypage/1.3.1/wui.citypage.min.js",
# 		"//icons.wxug.com/scripts/wui-precip/0.2.2/wui.precip.min.js",
# 		"//icons.wxug.com/scripts/wui-sitewide/2.2.2/wui.sitewide.min.js",
# 		];
# 		function scriptLoader(scripts) {
# 		!function(e,t,r){function n(){for(;d[0]&&"loaded"==d[0][f];)c=d.shift(),c[o]=!i.parentNode.insertBefore(c,i)}for(var s,a,c,d=[],i=e.scripts[0],o="onreadystatechange",f="readyState";s=r.shift();)a=e.createElement(t),"async"in i?(a.async=!1,e.head.appendChild(a)):i[f]?(d.push(a),a[o]=n):e.write("<"+t+' src="'+s+'" defer></'+t+">"),a.src=s}(document,"script",scripts);
# 		}
# 		//Load all required scripts for page
# 		Modernizr.load(initScripts);
# 	})();
# </script>
# <script>
# wui.bootstrapped.ajax_favorites = true; //added for wundermap favorites layer loading
# wui.bootstrapped.citylist = "";
# //wui.bootstrapped.citylist = "";
# </script>
# <script>
# wui.bootstrapped.recents = [];
# </script>
# <script>
# wui.bootstrapped.popular=[
# 	{
# 	url: "///",
# 	"lat": null,
# 	"lon": null,
# 	"name": "New York, NY",
# 	"type": "popular",
# 	"zmw": "10001.11.99999"
# 		},
# 	{
# 	url: "///",
# 	"lat": null,
# 	"lon": null,
# 	"name": "London, UK",
# 	"type": "popular",
# 	"zmw": "00000.40.03779"
# 		},
# 	{
# 	url: "///",
# 	"lat": null,
# 	"lon": null,
# 	"name": "Chicago, IL",
# 	"type": "popular",
# 	"zmw": "60290.1.99999"
# 		},
# 	{
# 	url: "///",
# 	"lat": null,
# 	"lon": null,
# 	"name": "Boston, MA",
# 	"type": "popular",
# 	"zmw": "02101.1.99999"
# 		},
# 	{
# 	url: "///",
# 	"lat": null,
# 	"lon": null,
# 	"name": "Houston, TX",
# 	"type": "popular",
# 	"zmw": "77001.1.99999"
# 		},
# 	{
# 	url: "///",
# 	"lat": null,
# 	"lon": null,
# 	"name": "San Francisco, CA",
# 	"type": "popular",
# 	"zmw": "94101.1.99999"
# 		},
# 	];
# if(!wui.bootstrapped.favorites) {
# 	wui.bootstrapped.popularcities = ["94102.1.99999","10001.11.99999","60290.1.99999","02108.1.99999","77001.1.99999","00000.40.03779"];
# }
# </script>
# 	<script>
# wui.bootstrapped.ads = {
#   amazonTest: {
#   url: 'http://www.amazon.com/gp/search?ie=UTF8&camp=1789&creative=9325&index=aps&keywords=outdoor%20gear&linkCode=ur2&tag=citypagetile-20&linkId=BREK7ZVZKKMA6FCM',
#   beacon: 'http://ir-na.amazon-adsystem.com/e/ir?t=citypagetile-20&l=ur2&o=1',
#   image: 'https://icons.wxug.com/graphics/amazonads/CityPageAd-Outdoor1.jpg'
#   },
# 	interval: 310000,
# 	enableAdRefresh: 1,
# 	ugc: false
# };
# </script>
# <script>
# wui.bootstrapped.citypage = {
# 	airports: [
# 		{
# 		code: "KVUO"
# 		}
# 	],
#   mosaic: {
#   map_type: "terrain"
#   },
# 	storm: {
# 	},
# 	photos: [
# 	],
# 	defconLevel: "5",
# 	city: "Portland",
# 	state: "OR",
# 	country: "United States",
# 	zip: "97217",
# 	zmw: "97217.1.99999",
# 	lat: "45.56999969",
# 	lon: "-122.69000244",
# 	tzname: "America/Los_Angeles",
# 	nearbyAirports: [
# 		"KVUO"
# 		, "KPDX"
# 		, "KHIO"
# 		, "KTTD"
# 	]
# };
# </script>
# <script>
# wui.bootstrapped.indexpage = {
# 	newhp: 1,
# 	althp: "",
# 	geoip: {
#   lat: "45.610298",
# 		lon: "-122.745499"
# 	},
# 	home_loc: {
# 		lat: "0.00",
# 		lon: "0.00",
# 		zmw: ""
# 	},
# 	location_found: 0,
#   mosaic: {
#   map_type: "lightmap"
#   },
# 	//wundermap Layers
# 	layers: [
# 		{
# 		layer: "WeatherStations",
# 		active: 1,
# 		//clickable: false,
# 		mode: "paddles",
# 		stationTypes: "ICAO,PWS",
# 		customClickHandler: function() { wui.indexpage.App.setSelectedStation(this); }
# 		}
# 	],
# 	video: {
# 		clipid: '',
# 		collid: 'news'
# 	},
# 	popups: {
# 		//'HpIterationInfo': null,
# 		'HpIterationInfo': '1',
# 	}
# };
# </script>
# <script>
# wui.bootstrapped.share = {
# 	domain: "www.wunderground.com",
# 	category: "CityPage",
# 	page: "ZipForecast",
# 	title: "Portland, OR (97217) Forecast",
# 		autoInitialize: false,
# 		image: "https://icons.wxug.com/i/c/a/partlycloudy.gif",
# 		now: "Partly Cloudy",
# 		temp_now: "65.4 &deg;F",
# 		high_now: " &deg;F",
# 		low_now: " &deg;F",
# 		tonight: "",
# 		high_tonight: " &deg;F",
# 		low_tonight: " &deg;F",
# 		tomorrow: "",
# 		high_tomorrow: " &deg;F",
# 		low_tomorrow: " &deg;F",
# 		loc: "Portland, OR",
# 		content_template: "<%= weather.response.location.city %>, <%= weather.response.location.state || weather.response.location.country_name %> - Now: <%= weather.current_observation.condition %> \(<%= weather.current_observation.temperature %><%= labels.temperature.units_nosymbol %>\) Tomorrow: <%= weather.forecast.days[1].summary.condition %> \(<%= weather.forecast.days[1].summary.high %><%= labels.temperature.units_nosymbol %>/<%= weather.forecast.days[1].summary.low %><%= labels.temperature.units_nosymbol %>\)"
# }
# </script>
# <script>
# 	wui.bootstrapped.videos = {
# 		play_icon: "//icons.wxug.com/graphics/playBtn.png",
# 		title: "Video Meat",
# 		clipid: '',
# 		playlists: [
# 		],
# 		showFeedbackTab: false,
# 		hasCondsCard: 0
# 	}
# </script>
# <script>
# wui.bootstrapped.precip = {
#   'lat': '45.573681',
#   'lon': '-122.691711',
#   'country': 'USA',
#   'chunky': '',
#   'baseUrl': '/us/or/portland',
#   'errors': {
#   statement: 'Oh no! Forecast temporarily unavailable.',
#   graph: 'Forecast temporarily unavailable.',
#   table: 'Forecast details are unavailable.'
#   }
# };
# </script>
# <script>
# 	var pwidget_config = {
#   clean: true,
#   copypaste: false,
#   shareQuote: false,
# 		defaults: {
# 		afterShare: false,
#   afterShareText: false,
#   shareAgain: false
# 		}
#   };
# </script>
# 		<script type="text/javascript">
#   if (window.innerWidth >= 768) {
# 		var npsOfferingId = '5724A21';
# 	}
# 	else {
# 		var npsOfferingId = '5724A22';
# 	}
# 	window.IBM_Meta = {
# 		offeringId: npsOfferingId,
# 		offeringName: 'wunderground.com',
# 		highLevelOfferingName: 'wundergroundDOTcom',
# 		userId: '',
# 		userEmail: '',
# 		userFirstName: '',
# 		userLastName: '',
# 		country: 'US',
# 		language: 'en',
# 		iuid: '',
# 		customerName: '',
# 		icn: '',
# 		daysSinceFirstLogin: 100,
# 		quarterlyIntercept: 'light',
# 		testData: false
# 	};
# </script>
# <script type="text/javascript" src="https://nebula-cdn.kampyle.com/we/28603/onsite/embed.js"></script>
# 		<!-- Adobe Analytics -->
# 	<script type="text/javascript" src="//icons.wxug.com/scripts/omniture-visitorapi.js?v=1.0"></script>
# 	<script type="text/javascript" src="//icons.wxug.com/scripts/omniture-appmeasurement.js?v=1.0"></script>
# 	<script type="text/javascript">
# 		s.pageName = "LocalWX";
# 		s.channel = "US Forecast";
# 		s.prop5 = "LocalWX";
# 		s.prop2 = "US Forecast > Portland, OR";
# 		// Member Type
# 		s.eVar12="non-member";
# 		// Ad Blocker
# 		s.eVar10 = window.noAdBlocker ? "no" : "yes";
# 		s.eVar54 = window.noAdBlocker ? "none" : "google";
# 		// Server
# 		s.server = "www.wunderground.com";
# 		// Events
# 		s.events = "event15";
# 		// Campaigns
# 		s.campaign = "";
# 		var s_code=s.t();if(s_code)document.write(s_code);
# 	</script>
# <!-- End Adobe Analytics -->
# <!-- Google Analytics -->
# 	<script>
# 	 (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	 })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	 ga('create', 'UA-5000463-5', 'auto');
# 	 ga('send', 'pageview');
# 	</script>
# <!-- End Google Analytics -->
# <!-- Begin comScore Tag -->
# 	<script>
# 	 var _comscore = _comscore || [];
# 	 _comscore.push({ c1: "2", c2: "6164429" });
# 	 (function() {
# 	 var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 	 s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# 	 el.parentNode.insertBefore(s, el);
# 	 })();
# 	</script>
# 	<noscript>
# 	 <img src="https://b.scorecardresearch.com/p?c1=2&c2=6164429&cv=2.0&cj=1" style="display:none;" />
# 	</noscript>
# <!-- End comScore Tag -->
# <!-- Start Nielsen 6.0 -->
# 	<script>
# 	 (function () {
# 	 var d = new Image(1, 1);
# 	 d.onerror = d.onload = function () {
# 	 d.onerror = d.onload = null;
# 	 };
# 	 d.src = ["//secure-us.imrworldwide.com/cgi-bin/m?ci=us-203014h&cg=0&cc=1&si=", escape(window.location.href), "&rp=", escape(document.referrer), "&ts=compact&rnd=", (new Date()).getTime()].join('');
# 	 })();
# 	</script>
# 	<noscript>
# 	 <img src="//secure-us.imrworldwide.com/cgi-bin/m?ci=us-203014h&amp;cg=0&amp;cc=1&amp;ts=noscript" width="1" height="1" alt="" style="display: none;" />
# 	</noscript>
# <!-- End Nielsen 6.0 -->
# <!-- Start IMC -->
# 	<script src="https://www.sc.pages02.net/lp/static/js/iMAWebCookie.js?13bc5b08-1575280ebee-df4cba773885eb54dfcebd294a039c37&h=www.pages02.net" type="text/javascript"></script>
# <!-- End IMC -->
# 		<div id="fb-root"></div>
# 	</body>
# </html>

# %% [markdown]
# Okay, this is really ugly. We'll have a hard time finding the information we need from here. First, go the website http://www.wunderground.com/weather-forecast/97217 directly and click on View - Developer - View Source. Search the page (using Control - F) for the word "curtemp", as in current temperature. We find the following:

# %%
<div id="curTemp" style="color: #f4b701;">
	<span class="wx-data" data-station="KORPORTL592" data-variable="temperature">
		<span class="wx-value">64.1</span>
		<span class="wx-unit">&deg;F</span>

# %% [markdown]
# In order to get 64.1 degrees, we can use BeautifulSoup. Note: we need to put an underscore after "class" because class is a reserved word in Python:

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.wunderground.com/weather-forecast/97217'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
temp = soup.find(id='curTemp').find(class_="wx-value").get_text()
print(temp)
# Out:
# 62.4

# %% [markdown]
# Suppose instead we wanted to print the city that our zipcode was located in. We see the source code here:

# %%
<div id="location">
		<h1 class="city-nav-header">
		Portland, OR

# %% [markdown]
# We can use BeautifulSoup once again:

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.wunderground.com/weather-forecast/97217'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
city = soup.find(id='location').find(class_="city-nav-header").get_text()
print(city)
# Out:
# 		Portland, OR
# 		(97217)

# %% [markdown]
# ### Exercise - BeautifulSoup 1
# Write a program using BeautifulSoup to print the information contained in the paragraphs (between the "p" terms) of the www.oes.edu website. It should look familiar!

# %%
#insert BeautifulSoup1

# %% [markdown]
# ### Exercise - Beautiful Soup2
# Count the number of hyperlink tags on the www.cnn.com website. You don't need to print them, just count them.

# %%
#insert Beautiful Soup 2

# %% [markdown]
# ### Exercise - Beautiful Soup3
# Write a program that prints out the OES faculty's titles.

# %%
#insert Beautiful Soup 3

# %% [markdown]
# ### Exercise - Beautiful Soup 4
# Write a program that prints out the OES faculty's phone numbers.

# %%
#insert BeautifulSoup 4

# %% [markdown]
# ### Exercise - Beautiful Soup 5
# Find the current condition of your city using id = "curCond".

# %%
#insert BeautifulSoup 5
